# %%
from qiskit.circuit import QuantumCircuit, Parameter
from iqcc_cloud_client import IQCC_Cloud
from qiskit_qm_provider import FluxTunableTransmonBackend, InputType, QMSamplerV2, QMSamplerOptions
from qiskit import transpile
from qiskit_qm_provider.backend.backend_utils import add_basic_macros_to_machine
import numpy as np
from pathlib import Path
import json
from rl_qoc.qua.iqcc import get_machine_from_iqcc

# Set your quantum computer backend
path = Path.home() / "iqcc_token.json"
with open(path, "r") as f:
    iqcc_config = json.load(f)

backend_name = "arbel"

machine, iqcc = get_machine_from_iqcc(backend_name, iqcc_config[backend_name])

add_basic_macros_to_machine(machine)
backend = FluxTunableTransmonBackend(machine)
# Out:
# 2025-10-08 12:37:25,364 - qm - INFO     - Starting session: b20c692b-9a49-4709-916d-9089d9480f6d
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/rl_qoc/helpers/__init__.py:9: UserWarning: pulse_utils is not available
#   warnings.warn("pulse_utils is not available")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/backend/backend_utils.py:215: UserWarning: Could not add default two qubit gates. Add it manually if necessary.
#   warnings.warn("Could not add default two qubit gates. Add it manually if necessary.")

# %%
backend.qm
# Out:
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/quam/components/channels.py:636: UserWarning: The 'thread' element argument is deprecated from qm.qua >= 1.2.2. Use 'core' instead.
#   warnings.warn(

# %%
backend.qm_config
# Out:
# {'version': 1,
#  'controllers': {'con1': {'fems': {5: {'type': 'LF',
#      'analog_outputs': {1: {'delay': 40,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       2: {'delay': 31,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       3: {'delay': 35,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       4: {'delay': 130,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       5: {'delay': 130,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       6: {'delay': 31,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0}}},
#     6: {'type': 'LF',
#      'analog_outputs': {1: {'delay': 35,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       2: {'delay': 28,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       3: {'delay': 35,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       4: {'delay': 130,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       5: {'delay': 35,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0}}},
#     7: {'type': 'LF',
#      'analog_outputs': {1: {'delay': 38,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       2: {'delay': 130,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       3: {'delay': 130,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       4: {'delay': 32,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       5: {'delay': 130,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0}}},
#     8: {'type': 'LF',
#      'analog_outputs': {1: {'delay': 33,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       2: {'delay': 38,
#        'shareable': False,
#        'filter': {'feedforward': [1.3334922395948767,
#          1.3334922395948767,
#          -0.4080153518617171,
#          -0.4080153518617171,
#          0.058101347053350016,
#          0.058101347053350016,
#          -0.008593636890869644,
#          -0.008593636890869644,
#          0.0080215670063451,
#          0.0080215670063451,
#          -0.005583211165663094,
#          -0.005583211165663094,
#          0.017166402044926088,
#          0.017166402044926088,
#          -0.0006211709958960018,
#          -0.0006211709958960018,
#          0.04152137663662725,
#          0.04152137663662725,
#          -0.0035372498964882162,
#          -0.0035372498964882162,
#          -0.06554516294558198,
#          -0.06554516294558198,
#          0.04123560357447376,
#          0.04123560357447376,
#          0.010119625046970983,
#          0.010119625046970983,
#          -0.006076094902122086,
#          -0.006076094902122086,
#          -0.011768064585419114,
#          -0.011768064585419114,
#          0.02027744992817454,
#          0.02027744992817454,
#          -0.02328441149169243,
#          -0.02328441149169243,
#          0.0025038033567109166,
#          0.0025038033567109166,
#          0.007104486889548373,
#          0.007104486889548373,
#          -0.009882135649392122,
#          -0.009882135649392122,
#          0.0008214013418904927,
#          0.0008214013418904927,
#          0.008395165856872512,
#          0.008395165856872512,
#          -0.011567767066632408,
#          -0.011567767066632408,
#          0.006888513152583514,
#          0.006888513152583514],
#         'exponential': [(-0.005382159771815775, 117.62112943776738),
#          (0.013612290534768423, 807.6196388302322),
#          (-0.02807856741913395, 1129.0717376520388),
#          (-0.13939966010945887, 6.602116085529952)]},
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'amplified',
#        'offset': 0.0},
#       3: {'delay': 34,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'amplified',
#        'offset': 0.0},
#       4: {'delay': 29,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0},
#       5: {'delay': 29,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'upsampling_mode': 'pulse',
#        'output_mode': 'direct',
#        'offset': 0.0}}},
#     1: {'type': 'MW',
#      'analog_outputs': {1: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': -2,
#        'upconverter_frequency': 7460000000},
#       2: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5050000000},
#       3: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5800000000},
#       4: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5800000000},
#       5: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 4950000000},
#       6: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5750000000},
#       7: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 6250000000}},
#      'analog_inputs': {1: {'band': 2,
#        'downconverter_frequency': 7460000000,
#        'sampling_rate': 1000000000.0,
#        'shareable': False}}},
#     2: {'type': 'MW',
#      'analog_outputs': {1: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': -2,
#        'upconverter_frequency': 7480000000},
#       2: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 4950000000},
#       3: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 6000000000},
#       4: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5700000000},
#       5: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 6300000000},
#       6: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5750000000}},
#      'analog_inputs': {1: {'band': 2,
#        'downconverter_frequency': 7480000000,
#        'sampling_rate': 1000000000.0,
#        'shareable': False}}},
#     3: {'type': 'MW',
#      'analog_outputs': {1: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': -2,
#        'upconverter_frequency': 7380000000},
#       2: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 4800000000},
#       3: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5590000000},
#       4: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 16,
#        'upconverter_frequency': 5590000000},
#       5: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 4800000000},
#       6: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 6250000000}},
#      'analog_inputs': {1: {'band': 2,
#        'downconverter_frequency': 7380000000,
#        'sampling_rate': 1000000000.0,
#        'shareable': False}}},
#     4: {'type': 'MW',
#      'analog_outputs': {1: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': -2,
#        'upconverter_frequency': 7460000000},
#       2: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5100000000},
#       3: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5900000000},
#       4: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 5900000000},
#       5: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 6300000000},
#       6: {'band': 2,
#        'delay': 0,
#        'shareable': False,
#        'sampling_rate': 1000000000.0,
#        'full_scale_power_dbm': 10,
#        'upconverter_frequency': 6000000000}},
#      'analog_inputs': {1: {'band': 2,
#        'downconverter_frequency': 7460000000,
#        'sampling_rate': 1000000000.0,
#        'shareable': False}}}}}},
#  'elements': {'qA1.xy': {'operations': {'x90': 'qA1.xy.x90_DragCosine.pulse',
#     'y90': 'qA1.xy.y90_DragCosine.pulse',
#     '-x90': 'qA1.xy.-x90_DragCosine.pulse',
#     '-y90': 'qA1.xy.-y90_DragCosine.pulse',
#     'x180': 'qA1.xy.x180_DragCosine.pulse',
#     'y180': 'qA1.xy.y180_DragCosine.pulse',
#     'saturation': 'qA1.xy.saturation.pulse',
#     'x90_Square': 'qA1.xy.x90_Square.pulse',
#     'y90_Square': 'qA1.xy.y90_Square.pulse',
#     '-x90_Square': 'qA1.xy.-x90_Square.pulse',
#     '-y90_Square': 'qA1.xy.-y90_Square.pulse',
#     'x180_Square': 'qA1.xy.x180_Square.pulse',
#     'y180_Square': 'qA1.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qA1.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qA1.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qA1.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qA1.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qA1.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qA1.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -335422498.2171612,
#    'core': 'qA1',
#    'MWInput': {'port': ('con1', 1, 2), 'upconverter': 1}},
#   'qA1.resonator': {'operations': {'const': 'qA1.resonator.const.pulse',
#     'readout': 'qA1.resonator.readout.pulse'},
#    'intermediate_frequency': -332400000,
#    'core': 'qA1',
#    'MWOutput': {'port': ('con1', 1, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 1, 1), 'upconverter': 1}},
#   'qA1.z': {'operations': {'const': 'qA1.z.const.pulse'},
#    'singleInput': {'port': ('con1', 5, 1)}},
#   'qA2.xy': {'operations': {'x90': 'qA2.xy.x90_DragCosine.pulse',
#     'y90': 'qA2.xy.y90_DragCosine.pulse',
#     '-x90': 'qA2.xy.-x90_DragCosine.pulse',
#     '-y90': 'qA2.xy.-y90_DragCosine.pulse',
#     'x180': 'qA2.xy.x180_DragCosine.pulse',
#     'y180': 'qA2.xy.y180_DragCosine.pulse',
#     'saturation': 'qA2.xy.saturation.pulse',
#     'x90_Square': 'qA2.xy.x90_Square.pulse',
#     'y90_Square': 'qA2.xy.y90_Square.pulse',
#     '-x90_Square': 'qA2.xy.-x90_Square.pulse',
#     '-y90_Square': 'qA2.xy.-y90_Square.pulse',
#     'x180_Square': 'qA2.xy.x180_Square.pulse',
#     'y180_Square': 'qA2.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qA2.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qA2.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qA2.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qA2.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qA2.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qA2.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -105249569.32706833,
#    'core': 'qA2',
#    'MWInput': {'port': ('con1', 1, 3), 'upconverter': 1}},
#   'qA2.resonator': {'operations': {'const': 'qA2.resonator.const.pulse',
#     'readout': 'qA2.resonator.readout.pulse'},
#    'intermediate_frequency': -63650000,
#    'core': 'qA2',
#    'MWOutput': {'port': ('con1', 1, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 1, 1), 'upconverter': 1}},
#   'qA2.z': {'operations': {'const': 'qA2.z.const.pulse'},
#    'singleInput': {'port': ('con1', 5, 2)}},
#   'qA3.xy': {'operations': {'x90': 'qA3.xy.x90_DragCosine.pulse',
#     'y90': 'qA3.xy.y90_DragCosine.pulse',
#     '-x90': 'qA3.xy.-x90_DragCosine.pulse',
#     '-y90': 'qA3.xy.-y90_DragCosine.pulse',
#     'x180': 'qA3.xy.x180_DragCosine.pulse',
#     'y180': 'qA3.xy.y180_DragCosine.pulse',
#     'saturation': 'qA3.xy.saturation.pulse',
#     'x90_Square': 'qA3.xy.x90_Square.pulse',
#     'y90_Square': 'qA3.xy.y90_Square.pulse',
#     '-x90_Square': 'qA3.xy.-x90_Square.pulse',
#     '-y90_Square': 'qA3.xy.-y90_Square.pulse',
#     'x180_Square': 'qA3.xy.x180_Square.pulse',
#     'y180_Square': 'qA3.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qA3.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qA3.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qA3.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qA3.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qA3.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qA3.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -497082867.05947304,
#    'core': 'qA3',
#    'MWInput': {'port': ('con1', 1, 4), 'upconverter': 1}},
#   'qA3.resonator': {'operations': {'const': 'qA3.resonator.const.pulse',
#     'readout': 'qA3.resonator.readout.pulse'},
#    'intermediate_frequency': 25800000.0,
#    'core': 'qA3',
#    'MWOutput': {'port': ('con1', 1, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 1, 1), 'upconverter': 1}},
#   'qA3.z': {'operations': {'const': 'qA3.z.const.pulse'},
#    'singleInput': {'port': ('con1', 5, 3)}},
#   'qA4.xy': {'operations': {'x90': 'qA4.xy.x90_DragCosine.pulse',
#     'y90': 'qA4.xy.y90_DragCosine.pulse',
#     '-x90': 'qA4.xy.-x90_DragCosine.pulse',
#     '-y90': 'qA4.xy.-y90_DragCosine.pulse',
#     'x180': 'qA4.xy.x180_DragCosine.pulse',
#     'y180': 'qA4.xy.y180_DragCosine.pulse',
#     'saturation': 'qA4.xy.saturation.pulse',
#     'x90_Square': 'qA4.xy.x90_Square.pulse',
#     'y90_Square': 'qA4.xy.y90_Square.pulse',
#     '-x90_Square': 'qA4.xy.-x90_Square.pulse',
#     '-y90_Square': 'qA4.xy.-y90_Square.pulse',
#     'x180_Square': 'qA4.xy.x180_Square.pulse',
#     'y180_Square': 'qA4.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qA4.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qA4.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qA4.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qA4.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qA4.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qA4.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 265910645.37786293,
#    'core': 'qA4',
#    'MWInput': {'port': ('con1', 1, 5), 'upconverter': 1}},
#   'qA4.resonator': {'operations': {'const': 'qA4.resonator.const.pulse',
#     'readout': 'qA4.resonator.readout.pulse'},
#    'intermediate_frequency': -208300000,
#    'core': 'qA4',
#    'MWOutput': {'port': ('con1', 1, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 1, 1), 'upconverter': 1}},
#   'qA4.z': {'operations': {'const': 'qA4.z.const.pulse'},
#    'singleInput': {'port': ('con1', 5, 4)}},
#   'qA5.xy': {'operations': {'x90': 'qA5.xy.x90_DragCosine.pulse',
#     'y90': 'qA5.xy.y90_DragCosine.pulse',
#     '-x90': 'qA5.xy.-x90_DragCosine.pulse',
#     '-y90': 'qA5.xy.-y90_DragCosine.pulse',
#     'x180': 'qA5.xy.x180_DragCosine.pulse',
#     'y180': 'qA5.xy.y180_DragCosine.pulse',
#     'saturation': 'qA5.xy.saturation.pulse',
#     'x90_Square': 'qA5.xy.x90_Square.pulse',
#     'y90_Square': 'qA5.xy.y90_Square.pulse',
#     '-x90_Square': 'qA5.xy.-x90_Square.pulse',
#     '-y90_Square': 'qA5.xy.-y90_Square.pulse',
#     'x180_Square': 'qA5.xy.x180_Square.pulse',
#     'y180_Square': 'qA5.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qA5.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qA5.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qA5.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qA5.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qA5.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qA5.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -50350239.30996513,
#    'core': 'qA5',
#    'MWInput': {'port': ('con1', 1, 6), 'upconverter': 1}},
#   'qA5.resonator': {'operations': {'const': 'qA5.resonator.const.pulse',
#     'readout': 'qA5.resonator.readout.pulse'},
#    'intermediate_frequency': 201900000,
#    'core': 'qA5',
#    'MWOutput': {'port': ('con1', 1, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 1, 1), 'upconverter': 1}},
#   'qA5.z': {'operations': {'const': 'qA5.z.const.pulse'},
#    'singleInput': {'port': ('con1', 5, 5)}},
#   'qA6.xy': {'operations': {'x90': 'qA6.xy.x90_DragCosine.pulse',
#     'y90': 'qA6.xy.y90_DragCosine.pulse',
#     '-x90': 'qA6.xy.-x90_DragCosine.pulse',
#     '-y90': 'qA6.xy.-y90_DragCosine.pulse',
#     'x180': 'qA6.xy.x180_DragCosine.pulse',
#     'y180': 'qA6.xy.y180_DragCosine.pulse',
#     'EF_x180': 'qA6.xy.EF_x180.pulse',
#     'saturation': 'qA6.xy.saturation.pulse',
#     'x90_Square': 'qA6.xy.x90_Square.pulse',
#     'y90_Square': 'qA6.xy.y90_Square.pulse',
#     '-x90_Square': 'qA6.xy.-x90_Square.pulse',
#     '-y90_Square': 'qA6.xy.-y90_Square.pulse',
#     'x180_Square': 'qA6.xy.x180_Square.pulse',
#     'y180_Square': 'qA6.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qA6.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qA6.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qA6.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qA6.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qA6.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qA6.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 175467281.4615078,
#    'core': 'qA6',
#    'MWInput': {'port': ('con1', 1, 7), 'upconverter': 1}},
#   'qA6.resonator': {'operations': {'const': 'qA6.resonator.const.pulse',
#     'readout': 'qA6.resonator.readout.pulse'},
#    'intermediate_frequency': 298350000.0,
#    'core': 'qA6',
#    'MWOutput': {'port': ('con1', 1, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 1, 1), 'upconverter': 1}},
#   'qA6.z': {'operations': {'const': 'qA6.z.const.pulse',
#     'Cz_unipolar.flux_pulse_control_qA6': 'qA6.z.Cz_unipolar.flux_pulse_control_qA6.pulse',
#     'Cz_flat_gaussian.flux_pulse_control_qA6': 'qA6.z.Cz_flat_gaussian.flux_pulse_control_qA6.pulse'},
#    'singleInput': {'port': ('con1', 5, 6)}},
#   'qB1.xy': {'operations': {'x90': 'qB1.xy.x90_DragCosine.pulse',
#     'y90': 'qB1.xy.y90_DragCosine.pulse',
#     '-x90': 'qB1.xy.-x90_DragCosine.pulse',
#     '-y90': 'qB1.xy.-y90_DragCosine.pulse',
#     'x180': 'qB1.xy.x180_DragCosine.pulse',
#     'y180': 'qB1.xy.y180_DragCosine.pulse',
#     'saturation': 'qB1.xy.saturation.pulse',
#     'x90_Square': 'qB1.xy.x90_Square.pulse',
#     'y90_Square': 'qB1.xy.y90_Square.pulse',
#     '-x90_Square': 'qB1.xy.-x90_Square.pulse',
#     '-y90_Square': 'qB1.xy.-y90_Square.pulse',
#     'x180_Square': 'qB1.xy.x180_Square.pulse',
#     'y180_Square': 'qB1.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qB1.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qB1.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qB1.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qB1.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qB1.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qB1.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 86308841.5792284,
#    'core': 'qB1',
#    'MWInput': {'port': ('con1', 2, 2), 'upconverter': 1}},
#   'qB1.resonator': {'operations': {'const': 'qB1.resonator.const.pulse',
#     'readout': 'qB1.resonator.readout.pulse'},
#    'intermediate_frequency': -314651273,
#    'core': 'qB1',
#    'MWOutput': {'port': ('con1', 2, 1)},
#    'smearing': 0,
#    'time_of_flight': 404,
#    'MWInput': {'port': ('con1', 2, 1), 'upconverter': 1}},
#   'qB1.z': {'operations': {'const': 'qB1.z.const.pulse'},
#    'singleInput': {'port': ('con1', 6, 1)}},
#   'qB2.xy': {'operations': {'x90': 'qB2.xy.x90_DragCosine.pulse',
#     'y90': 'qB2.xy.y90_DragCosine.pulse',
#     '-x90': 'qB2.xy.-x90_DragCosine.pulse',
#     '-y90': 'qB2.xy.-y90_DragCosine.pulse',
#     'x180': 'qB2.xy.x180_DragCosine.pulse',
#     'y180': 'qB2.xy.y180_DragCosine.pulse',
#     'saturation': 'qB2.xy.saturation.pulse',
#     'x90_Square': 'qB2.xy.x90_Square.pulse',
#     'y90_Square': 'qB2.xy.y90_Square.pulse',
#     '-x90_Square': 'qB2.xy.-x90_Square.pulse',
#     '-y90_Square': 'qB2.xy.-y90_Square.pulse',
#     'x180_Square': 'qB2.xy.x180_Square.pulse',
#     'y180_Square': 'qB2.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qB2.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qB2.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qB2.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qB2.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qB2.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qB2.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -58526356.93252468,
#    'core': 'qB2',
#    'MWInput': {'port': ('con1', 2, 3), 'upconverter': 1}},
#   'qB2.resonator': {'operations': {'const': 'qB2.resonator.const.pulse',
#     'readout': 'qB2.resonator.readout.pulse'},
#    'intermediate_frequency': -49613609,
#    'core': 'qB2',
#    'MWOutput': {'port': ('con1', 2, 1)},
#    'smearing': 0,
#    'time_of_flight': 404,
#    'MWInput': {'port': ('con1', 2, 1), 'upconverter': 1}},
#   'qB2.z': {'operations': {'const': 'qB2.z.const.pulse'},
#    'singleInput': {'port': ('con1', 6, 2)}},
#   'qB3.xy': {'operations': {'x90': 'qB3.xy.x90_DragCosine.pulse',
#     'y90': 'qB3.xy.y90_DragCosine.pulse',
#     '-x90': 'qB3.xy.-x90_DragCosine.pulse',
#     '-y90': 'qB3.xy.-y90_DragCosine.pulse',
#     'x180': 'qB3.xy.x180_DragCosine.pulse',
#     'y180': 'qB3.xy.y180_DragCosine.pulse',
#     'saturation': 'qB3.xy.saturation.pulse',
#     'x90_Square': 'qB3.xy.x90_Square.pulse',
#     'y90_Square': 'qB3.xy.y90_Square.pulse',
#     '-x90_Square': 'qB3.xy.-x90_Square.pulse',
#     '-y90_Square': 'qB3.xy.-y90_Square.pulse',
#     'x180_Square': 'qB3.xy.x180_Square.pulse',
#     'y180_Square': 'qB3.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qB3.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qB3.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qB3.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qB3.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qB3.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qB3.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -477423589.3688917,
#    'core': 'qB3',
#    'MWInput': {'port': ('con1', 2, 4), 'upconverter': 1}},
#   'qB3.resonator': {'operations': {'const': 'qB3.resonator.const.pulse',
#     'readout': 'qB3.resonator.readout.pulse'},
#    'intermediate_frequency': 53200000,
#    'core': 'qB3',
#    'MWOutput': {'port': ('con1', 2, 1)},
#    'smearing': 0,
#    'time_of_flight': 404,
#    'MWInput': {'port': ('con1', 2, 1), 'upconverter': 1}},
#   'qB3.z': {'operations': {'const': 'qB3.z.const.pulse'},
#    'singleInput': {'port': ('con1', 6, 3)}},
#   'qB4.xy': {'operations': {'x90': 'qB4.xy.x90_DragCosine.pulse',
#     'y90': 'qB4.xy.y90_DragCosine.pulse',
#     '-x90': 'qB4.xy.-x90_DragCosine.pulse',
#     '-y90': 'qB4.xy.-y90_DragCosine.pulse',
#     'x180': 'qB4.xy.x180_DragCosine.pulse',
#     'y180': 'qB4.xy.y180_DragCosine.pulse',
#     'saturation': 'qB4.xy.saturation.pulse',
#     'x90_Square': 'qB4.xy.x90_Square.pulse',
#     'y90_Square': 'qB4.xy.y90_Square.pulse',
#     '-x90_Square': 'qB4.xy.-x90_Square.pulse',
#     '-y90_Square': 'qB4.xy.-y90_Square.pulse',
#     'x180_Square': 'qB4.xy.x180_Square.pulse',
#     'y180_Square': 'qB4.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qB4.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qB4.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qB4.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qB4.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qB4.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qB4.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 282146247.2890806,
#    'core': 'qB4',
#    'MWInput': {'port': ('con1', 2, 5), 'upconverter': 1}},
#   'qB4.resonator': {'operations': {'const': 'qB4.resonator.const.pulse',
#     'readout': 'qB4.resonator.readout.pulse'},
#    'intermediate_frequency': 263500000,
#    'core': 'qB4',
#    'MWOutput': {'port': ('con1', 2, 1)},
#    'smearing': 0,
#    'time_of_flight': 404,
#    'MWInput': {'port': ('con1', 2, 1), 'upconverter': 1}},
#   'qB4.z': {'operations': {'const': 'qB4.z.const.pulse'},
#    'singleInput': {'port': ('con1', 6, 4)}},
#   'qB5.xy': {'operations': {'x90': 'qB5.xy.x90_DragCosine.pulse',
#     'y90': 'qB5.xy.y90_DragCosine.pulse',
#     '-x90': 'qB5.xy.-x90_DragCosine.pulse',
#     '-y90': 'qB5.xy.-y90_DragCosine.pulse',
#     'x180': 'qB5.xy.x180_DragCosine.pulse',
#     'y180': 'qB5.xy.y180_DragCosine.pulse',
#     'saturation': 'qB5.xy.saturation.pulse',
#     'x90_Square': 'qB5.xy.x90_Square.pulse',
#     'y90_Square': 'qB5.xy.y90_Square.pulse',
#     '-x90_Square': 'qB5.xy.-x90_Square.pulse',
#     '-y90_Square': 'qB5.xy.-y90_Square.pulse',
#     'x180_Square': 'qB5.xy.x180_Square.pulse',
#     'y180_Square': 'qB5.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qB5.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qB5.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qB5.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qB5.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qB5.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qB5.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 130974809.07225513,
#    'core': 'qB5',
#    'MWInput': {'port': ('con1', 2, 6), 'upconverter': 1}},
#   'qB5.resonator': {'operations': {'const': 'qB5.resonator.const.pulse',
#     'readout': 'qB5.resonator.readout.pulse'},
#    'intermediate_frequency': 188600000,
#    'core': 'qB5',
#    'MWOutput': {'port': ('con1', 2, 1)},
#    'smearing': 0,
#    'time_of_flight': 404,
#    'MWInput': {'port': ('con1', 2, 1), 'upconverter': 1}},
#   'qB5.z': {'operations': {'const': 'qB5.z.const.pulse'},
#    'singleInput': {'port': ('con1', 6, 5)}},
#   'qC1.xy': {'operations': {'x90': 'qC1.xy.x90_DragCosine.pulse',
#     'y90': 'qC1.xy.y90_DragCosine.pulse',
#     '-x90': 'qC1.xy.-x90_DragCosine.pulse',
#     '-y90': 'qC1.xy.-y90_DragCosine.pulse',
#     'x180': 'qC1.xy.x180_DragCosine.pulse',
#     'y180': 'qC1.xy.y180_DragCosine.pulse',
#     'saturation': 'qC1.xy.saturation.pulse',
#     'x90_Square': 'qC1.xy.x90_Square.pulse',
#     'y90_Square': 'qC1.xy.y90_Square.pulse',
#     '-x90_Square': 'qC1.xy.-x90_Square.pulse',
#     '-y90_Square': 'qC1.xy.-y90_Square.pulse',
#     'x180_Square': 'qC1.xy.x180_Square.pulse',
#     'y180_Square': 'qC1.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qC1.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qC1.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qC1.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qC1.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qC1.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qC1.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 185894377.941288,
#    'core': 'qC1',
#    'MWInput': {'port': ('con1', 3, 2), 'upconverter': 1}},
#   'qC1.resonator': {'operations': {'const': 'qC1.resonator.const.pulse',
#     'readout': 'qC1.resonator.readout.pulse'},
#    'intermediate_frequency': -227300000,
#    'core': 'qC1',
#    'MWOutput': {'port': ('con1', 3, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 3, 1), 'upconverter': 1}},
#   'qC1.z': {'operations': {'const': 'qC1.z.const.pulse'},
#    'singleInput': {'port': ('con1', 7, 1)}},
#   'qC2.xy': {'operations': {'x90': 'qC2.xy.x90_DragCosine.pulse',
#     'y90': 'qC2.xy.y90_DragCosine.pulse',
#     '-x90': 'qC2.xy.-x90_DragCosine.pulse',
#     '-y90': 'qC2.xy.-y90_DragCosine.pulse',
#     'x180': 'qC2.xy.x180_DragCosine.pulse',
#     'y180': 'qC2.xy.y180_DragCosine.pulse',
#     'EF_x180': 'qC2.xy.EF_x180.pulse',
#     'saturation': 'qC2.xy.saturation.pulse',
#     'x90_Square': 'qC2.xy.x90_Square.pulse',
#     'y90_Square': 'qC2.xy.y90_Square.pulse',
#     '-x90_Square': 'qC2.xy.-x90_Square.pulse',
#     '-y90_Square': 'qC2.xy.-y90_Square.pulse',
#     'x180_Square': 'qC2.xy.x180_Square.pulse',
#     'y180_Square': 'qC2.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qC2.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qC2.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qC2.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qC2.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qC2.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qC2.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 274959180.61757946,
#    'core': 'qC2',
#    'MWInput': {'port': ('con1', 3, 3), 'upconverter': 1}},
#   'qC2.resonator': {'operations': {'const': 'qC2.resonator.const.pulse',
#     'readout': 'qC2.resonator.readout.pulse'},
#    'intermediate_frequency': 40300000,
#    'core': 'qC2',
#    'MWOutput': {'port': ('con1', 3, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 3, 1), 'upconverter': 1}},
#   'qC2.z': {'operations': {'const': 'qC2.z.const.pulse'},
#    'singleInput': {'port': ('con1', 7, 2)}},
#   'qC3.xy': {'operations': {'x90': 'qC3.xy.x90_DragCosine.pulse',
#     'y90': 'qC3.xy.y90_DragCosine.pulse',
#     '-x90': 'qC3.xy.-x90_DragCosine.pulse',
#     '-y90': 'qC3.xy.-y90_DragCosine.pulse',
#     'x180': 'qC3.xy.x180_DragCosine.pulse',
#     'y180': 'qC3.xy.y180_DragCosine.pulse',
#     'saturation': 'qC3.xy.saturation.pulse',
#     'x90_Square': 'qC3.xy.x90_Square.pulse',
#     'y90_Square': 'qC3.xy.y90_Square.pulse',
#     '-x90_Square': 'qC3.xy.-x90_Square.pulse',
#     '-y90_Square': 'qC3.xy.-y90_Square.pulse',
#     'x180_Square': 'qC3.xy.x180_Square.pulse',
#     'y180_Square': 'qC3.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qC3.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qC3.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qC3.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qC3.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qC3.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qC3.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 121125000,
#    'core': 'qC3',
#    'MWInput': {'port': ('con1', 3, 4), 'upconverter': 1}},
#   'qC3.resonator': {'operations': {'const': 'qC3.resonator.const.pulse',
#     'readout': 'qC3.resonator.readout.pulse'},
#    'intermediate_frequency': 143350000,
#    'core': 'qC3',
#    'MWOutput': {'port': ('con1', 3, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 3, 1), 'upconverter': 1}},
#   'qC3.z': {'operations': {'const': 'qC3.z.const.pulse'},
#    'singleInput': {'port': ('con1', 7, 3)}},
#   'qC4.xy': {'operations': {'x90': 'qC4.xy.x90_DragCosine.pulse',
#     'y90': 'qC4.xy.y90_DragCosine.pulse',
#     '-x90': 'qC4.xy.-x90_DragCosine.pulse',
#     '-y90': 'qC4.xy.-y90_DragCosine.pulse',
#     'x180': 'qC4.xy.x180_DragCosine.pulse',
#     'y180': 'qC4.xy.y180_DragCosine.pulse',
#     'saturation': 'qC4.xy.saturation.pulse',
#     'x90_Square': 'qC4.xy.x90_Square.pulse',
#     'y90_Square': 'qC4.xy.y90_Square.pulse',
#     '-x90_Square': 'qC4.xy.-x90_Square.pulse',
#     '-y90_Square': 'qC4.xy.-y90_Square.pulse',
#     'x180_Square': 'qC4.xy.x180_Square.pulse',
#     'y180_Square': 'qC4.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qC4.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qC4.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qC4.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qC4.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qC4.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qC4.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 352119501.33297634,
#    'core': 'qC4',
#    'MWInput': {'port': ('con1', 3, 5), 'upconverter': 1}},
#   'qC4.resonator': {'operations': {'const': 'qC4.resonator.const.pulse',
#     'readout': 'qC4.resonator.readout.pulse'},
#    'intermediate_frequency': -109700000,
#    'core': 'qC4',
#    'MWOutput': {'port': ('con1', 3, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 3, 1), 'upconverter': 1}},
#   'qC4.z': {'operations': {'const': 'qC4.z.const.pulse'},
#    'singleInput': {'port': ('con1', 7, 4)}},
#   'qC5.xy': {'operations': {'x90': 'qC5.xy.x90_DragCosine.pulse',
#     'y90': 'qC5.xy.y90_DragCosine.pulse',
#     '-x90': 'qC5.xy.-x90_DragCosine.pulse',
#     '-y90': 'qC5.xy.-y90_DragCosine.pulse',
#     'x180': 'qC5.xy.x180_DragCosine.pulse',
#     'y180': 'qC5.xy.y180_DragCosine.pulse',
#     'saturation': 'qC5.xy.saturation.pulse',
#     'x90_Square': 'qC5.xy.x90_Square.pulse',
#     'y90_Square': 'qC5.xy.y90_Square.pulse',
#     '-x90_Square': 'qC5.xy.-x90_Square.pulse',
#     '-y90_Square': 'qC5.xy.-y90_Square.pulse',
#     'x180_Square': 'qC5.xy.x180_Square.pulse',
#     'y180_Square': 'qC5.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qC5.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qC5.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qC5.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qC5.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qC5.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qC5.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -25722529.54728031,
#    'core': 'qC5',
#    'MWInput': {'port': ('con1', 3, 6), 'upconverter': 1}},
#   'qC5.resonator': {'operations': {'const': 'qC5.resonator.const.pulse',
#     'readout': 'qC5.resonator.readout.pulse'},
#    'intermediate_frequency': 280700000,
#    'core': 'qC5',
#    'MWOutput': {'port': ('con1', 3, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 3, 1), 'upconverter': 1}},
#   'qC5.z': {'operations': {'const': 'qC5.z.const.pulse'},
#    'singleInput': {'port': ('con1', 7, 5)}},
#   'qD1.xy': {'operations': {'x90': 'qD1.xy.x90_DragCosine.pulse',
#     'y90': 'qD1.xy.y90_DragCosine.pulse',
#     '-x90': 'qD1.xy.-x90_DragCosine.pulse',
#     '-y90': 'qD1.xy.-y90_DragCosine.pulse',
#     'x180': 'qD1.xy.x180_DragCosine.pulse',
#     'y180': 'qD1.xy.y180_DragCosine.pulse',
#     'saturation': 'qD1.xy.saturation.pulse',
#     'x90_Square': 'qD1.xy.x90_Square.pulse',
#     'y90_Square': 'qD1.xy.y90_Square.pulse',
#     '-x90_Square': 'qD1.xy.-x90_Square.pulse',
#     '-y90_Square': 'qD1.xy.-y90_Square.pulse',
#     'x180_Square': 'qD1.xy.x180_Square.pulse',
#     'y180_Square': 'qD1.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qD1.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qD1.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qD1.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qD1.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qD1.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qD1.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 260002823.5991583,
#    'core': 'qD1',
#    'MWInput': {'port': ('con1', 4, 2), 'upconverter': 1}},
#   'qD1.resonator': {'operations': {'const': 'qD1.resonator.const.pulse',
#     'readout': 'qD1.resonator.readout.pulse'},
#    'intermediate_frequency': -306440738,
#    'core': 'qD1',
#    'MWOutput': {'port': ('con1', 4, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 4, 1), 'upconverter': 1}},
#   'qD1.z': {'operations': {'const': 'qD1.z.const.pulse'},
#    'singleInput': {'port': ('con1', 8, 1)}},
#   'qD2.xy': {'operations': {'x90': 'qD2.xy.x90_DragCosine.pulse',
#     'y90': 'qD2.xy.y90_DragCosine.pulse',
#     '-x90': 'qD2.xy.-x90_DragCosine.pulse',
#     '-y90': 'qD2.xy.-y90_DragCosine.pulse',
#     'x180': 'qD2.xy.x180_DragCosine.pulse',
#     'y180': 'qD2.xy.y180_DragCosine.pulse',
#     'saturation': 'qD2.xy.saturation.pulse',
#     'x90_Square': 'qD2.xy.x90_Square.pulse',
#     'y90_Square': 'qD2.xy.y90_Square.pulse',
#     '-x90_Square': 'qD2.xy.-x90_Square.pulse',
#     '-y90_Square': 'qD2.xy.-y90_Square.pulse',
#     'x180_Square': 'qD2.xy.x180_Square.pulse',
#     'y180_Square': 'qD2.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qD2.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qD2.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qD2.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qD2.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qD2.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qD2.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 135883858.05229187,
#    'core': 'qD2',
#    'MWInput': {'port': ('con1', 4, 3), 'upconverter': 1}},
#   'qD2.resonator': {'operations': {'const': 'qD2.resonator.const.pulse',
#     'readout': 'qD2.resonator.readout.pulse'},
#    'intermediate_frequency': -51383519,
#    'core': 'qD2',
#    'MWOutput': {'port': ('con1', 4, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 4, 1), 'upconverter': 1}},
#   'qD2.z': {'operations': {'const': 'qD2.z.const.pulse',
#     'Cz_unipolar.flux_pulse_control_qD1': 'qD2.z.Cz_unipolar.flux_pulse_control_qD1.pulse'},
#    'singleInput': {'port': ('con1', 8, 2)}},
#   'qD3.xy': {'operations': {'x90': 'qD3.xy.x90_DragCosine.pulse',
#     'y90': 'qD3.xy.y90_DragCosine.pulse',
#     '-x90': 'qD3.xy.-x90_DragCosine.pulse',
#     '-y90': 'qD3.xy.-y90_DragCosine.pulse',
#     'x180': 'qD3.xy.x180_DragCosine.pulse',
#     'y180': 'qD3.xy.y180_DragCosine.pulse',
#     'EF_x180': 'qD3.xy.EF_x180.pulse',
#     'saturation': 'qD3.xy.saturation.pulse',
#     'x90_Square': 'qD3.xy.x90_Square.pulse',
#     'y90_Square': 'qD3.xy.y90_Square.pulse',
#     '-x90_Square': 'qD3.xy.-x90_Square.pulse',
#     '-y90_Square': 'qD3.xy.-y90_Square.pulse',
#     'x180_Square': 'qD3.xy.x180_Square.pulse',
#     'y180_Square': 'qD3.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qD3.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qD3.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qD3.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qD3.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qD3.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qD3.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 165355132.26792908,
#    'core': 'qD3',
#    'MWInput': {'port': ('con1', 4, 4), 'upconverter': 1}},
#   'qD3.resonator': {'operations': {'const': 'qD3.resonator.const.pulse',
#     'readout': 'qD3.resonator.readout.pulse'},
#    'intermediate_frequency': 64274825,
#    'core': 'qD3',
#    'MWOutput': {'port': ('con1', 4, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 4, 1), 'upconverter': 1}},
#   'qD3.z': {'operations': {'const': 'qD3.z.const.pulse'},
#    'singleInput': {'port': ('con1', 8, 3)}},
#   'qD4.xy': {'operations': {'x90': 'qD4.xy.x90_DragCosine.pulse',
#     'y90': 'qD4.xy.y90_DragCosine.pulse',
#     '-x90': 'qD4.xy.-x90_DragCosine.pulse',
#     '-y90': 'qD4.xy.-y90_DragCosine.pulse',
#     'x180': 'qD4.xy.x180_DragCosine.pulse',
#     'y180': 'qD4.xy.y180_DragCosine.pulse',
#     'saturation': 'qD4.xy.saturation.pulse',
#     'x90_Square': 'qD4.xy.x90_Square.pulse',
#     'y90_Square': 'qD4.xy.y90_Square.pulse',
#     '-x90_Square': 'qD4.xy.-x90_Square.pulse',
#     '-y90_Square': 'qD4.xy.-y90_Square.pulse',
#     'x180_Square': 'qD4.xy.x180_Square.pulse',
#     'y180_Square': 'qD4.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qD4.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qD4.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qD4.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qD4.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qD4.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qD4.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': 332486069.72641945,
#    'core': 'qD4',
#    'MWInput': {'port': ('con1', 4, 5), 'upconverter': 1}},
#   'qD4.resonator': {'operations': {'const': 'qD4.resonator.const.pulse',
#     'readout': 'qD4.resonator.readout.pulse'},
#    'intermediate_frequency': 278850000,
#    'core': 'qD4',
#    'MWOutput': {'port': ('con1', 4, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 4, 1), 'upconverter': 1}},
#   'qD4.z': {'operations': {'const': 'qD4.z.const.pulse'},
#    'singleInput': {'port': ('con1', 8, 4)}},
#   'qD5.xy': {'operations': {'x90': 'qD5.xy.x90_DragCosine.pulse',
#     'y90': 'qD5.xy.y90_DragCosine.pulse',
#     '-x90': 'qD5.xy.-x90_DragCosine.pulse',
#     '-y90': 'qD5.xy.-y90_DragCosine.pulse',
#     'x180': 'qD5.xy.x180_DragCosine.pulse',
#     'y180': 'qD5.xy.y180_DragCosine.pulse',
#     'saturation': 'qD5.xy.saturation.pulse',
#     'x90_Square': 'qD5.xy.x90_Square.pulse',
#     'y90_Square': 'qD5.xy.y90_Square.pulse',
#     '-x90_Square': 'qD5.xy.-x90_Square.pulse',
#     '-y90_Square': 'qD5.xy.-y90_Square.pulse',
#     'x180_Square': 'qD5.xy.x180_Square.pulse',
#     'y180_Square': 'qD5.xy.y180_Square.pulse',
#     'x90_DragCosine': 'qD5.xy.x90_DragCosine.pulse',
#     'y90_DragCosine': 'qD5.xy.y90_DragCosine.pulse',
#     '-x90_DragCosine': 'qD5.xy.-x90_DragCosine.pulse',
#     '-y90_DragCosine': 'qD5.xy.-y90_DragCosine.pulse',
#     'x180_DragCosine': 'qD5.xy.x180_DragCosine.pulse',
#     'y180_DragCosine': 'qD5.xy.y180_DragCosine.pulse'},
#    'intermediate_frequency': -99133989.66804218,
#    'core': 'qD5',
#    'MWInput': {'port': ('con1', 4, 6), 'upconverter': 1}},
#   'qD5.resonator': {'operations': {'const': 'qD5.resonator.const.pulse',
#     'readout': 'qD5.resonator.readout.pulse'},
#    'intermediate_frequency': 202700000,
#    'core': 'qD5',
#    'MWOutput': {'port': ('con1', 4, 1)},
#    'smearing': 0,
#    'time_of_flight': 392,
#    'MWInput': {'port': ('con1', 4, 1), 'upconverter': 1}},
#   'qD5.z': {'operations': {'const': 'qD5.z.const.pulse'},
#    'singleInput': {'port': ('con1', 8, 5)}}},
#  'pulses': {'const_pulse': {'operation': 'control',
#    'length': 1000,
#    'waveforms': {'I': 'const_wf', 'Q': 'zero_wf'}},
#   'qA1.xy.saturation.pulse': {'operation': 'control',
#    'length': 20000,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.saturation.wf.I',
#     'Q': 'qA1.xy.saturation.wf.Q'}},
#   'qA1.xy.x90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.x90_Square.wf.I',
#     'Q': 'qA1.xy.x90_Square.wf.Q'}},
#   'qA1.xy.y90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.y90_Square.wf.I',
#     'Q': 'qA1.xy.y90_Square.wf.Q'}},
#   'qA1.xy.-x90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.-x90_Square.wf.I',
#     'Q': 'qA1.xy.-x90_Square.wf.Q'}},
#   'qA1.xy.-y90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.-y90_Square.wf.I',
#     'Q': 'qA1.xy.-y90_Square.wf.Q'}},
#   'qA1.xy.x180_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.x180_Square.wf.I',
#     'Q': 'qA1.xy.x180_Square.wf.Q'}},
#   'qA1.xy.y180_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.y180_Square.wf.I',
#     'Q': 'qA1.xy.y180_Square.wf.Q'}},
#   'qA1.xy.x90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.x90_DragCosine.wf.I',
#     'Q': 'qA1.xy.x90_DragCosine.wf.Q'}},
#   'qA1.xy.y90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.y90_DragCosine.wf.I',
#     'Q': 'qA1.xy.y90_DragCosine.wf.Q'}},
#   'qA1.xy.-x90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.-x90_DragCosine.wf.I',
#     'Q': 'qA1.xy.-x90_DragCosine.wf.Q'}},
#   'qA1.xy.-y90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.-y90_DragCosine.wf.I',
#     'Q': 'qA1.xy.-y90_DragCosine.wf.Q'}},
#   'qA1.xy.x180_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.x180_DragCosine.wf.I',
#     'Q': 'qA1.xy.x180_DragCosine.wf.Q'}},
#   'qA1.xy.y180_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.xy.y180_DragCosine.wf.I',
#     'Q': 'qA1.xy.y180_DragCosine.wf.Q'}},
#   'qA1.resonator.const.pulse': {'operation': 'control',
#    'length': 100,
#    'waveforms': {'I': 'qA1.resonator.const.wf.I',
#     'Q': 'qA1.resonator.const.wf.Q'}},
#   'qA1.resonator.readout.pulse': {'operation': 'measurement',
#    'length': 1500,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA1.resonator.readout.wf.I',
#     'Q': 'qA1.resonator.readout.wf.Q'},
#    'integration_weights': {'iw1': 'qA1.resonator.readout.iw1',
#     'iw2': 'qA1.resonator.readout.iw2',
#     'iw3': 'qA1.resonator.readout.iw3'}},
#   'qA1.z.const.pulse': {'operation': 'control',
#    'length': 100,
#    'waveforms': {'single': 'qA1.z.const.wf'}},
#   'qA2.xy.saturation.pulse': {'operation': 'control',
#    'length': 20000,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.saturation.wf.I',
#     'Q': 'qA2.xy.saturation.wf.Q'}},
#   'qA2.xy.x90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.x90_Square.wf.I',
#     'Q': 'qA2.xy.x90_Square.wf.Q'}},
#   'qA2.xy.y90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.y90_Square.wf.I',
#     'Q': 'qA2.xy.y90_Square.wf.Q'}},
#   'qA2.xy.-x90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.-x90_Square.wf.I',
#     'Q': 'qA2.xy.-x90_Square.wf.Q'}},
#   'qA2.xy.-y90_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.-y90_Square.wf.I',
#     'Q': 'qA2.xy.-y90_Square.wf.Q'}},
#   'qA2.xy.x180_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.x180_Square.wf.I',
#     'Q': 'qA2.xy.x180_Square.wf.Q'}},
#   'qA2.xy.y180_Square.pulse': {'operation': 'control',
#    'length': 40,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.y180_Square.wf.I',
#     'Q': 'qA2.xy.y180_Square.wf.Q'}},
#   'qA2.xy.x90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.x90_DragCosine.wf.I',
#     'Q': 'qA2.xy.x90_DragCosine.wf.Q'}},
#   'qA2.xy.y90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.y90_DragCosine.wf.I',
#     'Q': 'qA2.xy.y90_DragCosine.wf.Q'}},
#   'qA2.xy.-x90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.-x90_DragCosine.wf.I',
#     'Q': 'qA2.xy.-x90_DragCosine.wf.Q'}},
#   'qA2.xy.-y90_DragCosine.pulse': {'operation': 'control',
#    'length': 48,
#    'digital_marker': 'ON',
#    'waveforms': {'I': 'qA2.xy.-y90_DragCosine.wf.I',
# ...
#     0.0]},
#   'qD5.xy.x180_DragCosine.wf.Q': {'type': 'arbitrary',
#    'samples': [0.0,
#     -0.007278643619140925,
#     -0.01442739967046401,
#     -0.021318698432876225,
#     -0.027829564516704416,
#     -0.0338438113624374,
#     -0.039254114592632915,
#     -0.043963927217975644,
#     -0.04788920252058884,
#     -0.05095989386970585,
#     -0.05312120470545567,
#     -0.05433456638477192,
#     -0.05457832643974215,
#     -0.053848134966410624,
#     -0.052157022248917495,
#     -0.04953516623376964,
#     -0.046029354003670295,
#     -0.04170214686091981,
#     -0.03663076391949401,
#     -0.030905704128125946,
#     -0.024629131314421744,
#     -0.0179130510689367,
#     -0.010877312002758472,
#     -0.0036474670462026903,
#     0.0036474670462026764,
#     0.010877312002758458,
#     0.01791305106893671,
#     0.024629131314421706,
#     0.030905704128125915,
#     0.03663076391949401,
#     0.041702146860919796,
#     0.04602935400367029,
#     0.04953516623376964,
#     0.052157022248917495,
#     0.053848134966410624,
#     0.05457832643974215,
#     0.05433456638477192,
#     0.05312120470545567,
#     0.05095989386970587,
#     0.04788920252058886,
#     0.043963927217975665,
#     0.039254114592632935,
#     0.03384381136243739,
#     0.02782956451670444,
#     0.021318698432876246,
#     0.014427399670464032,
#     0.007278643619140941,
#     -3.5127073403516365e-17]},
#   'qD5.xy.y180_DragCosine.wf.I': {'type': 'arbitrary',
#    'samples': [0.0,
#     0.007278643619140925,
#     0.01442739967046401,
#     0.021318698432876225,
#     0.027829564516704416,
#     0.0338438113624374,
#     0.039254114592632915,
#     0.04396392721797565,
#     0.04788920252058885,
#     0.050959893869705855,
#     0.05312120470545568,
#     0.05433456638477193,
#     0.054578326439742156,
#     0.05384813496641064,
#     0.05215702224891751,
#     0.049535166233769655,
#     0.04602935400367031,
#     0.041702146860919824,
#     0.036630763919494026,
#     0.030905704128125964,
#     0.02462913131442176,
#     0.017913051068936717,
#     0.01087731200275849,
#     0.0036474670462027085,
#     -0.003647467046202658,
#     -0.010877312002758441,
#     -0.017913051068936692,
#     -0.02462913131442169,
#     -0.030905704128125898,
#     -0.036630763919494,
#     -0.04170214686091978,
#     -0.046029354003670274,
#     -0.04953516623376963,
#     -0.05215702224891748,
#     -0.05384813496641061,
#     -0.05457832643974214,
#     -0.054334566384771917,
#     -0.053121204705455664,
#     -0.05095989386970586,
#     -0.047889202520588856,
#     -0.04396392721797566,
#     -0.039254114592632935,
#     -0.03384381136243739,
#     -0.02782956451670444,
#     -0.021318698432876246,
#     -0.014427399670464032,
#     -0.007278643619140941,
#     3.5127073403516365e-17]},
#   'qD5.xy.y180_DragCosine.wf.Q': {'type': 'arbitrary',
#    'samples': [0.0,
#     0.001331433108625292,
#     0.005301972979135539,
#     0.011840765233477631,
#     0.020831124968965976,
#     0.03211261900313521,
#     0.045483928807682025,
#     0.06070644304237206,
#     0.07750851558005926,
#     0.09559031303826006,
#     0.11462916531296712,
#     0.13428532363429957,
#     0.15420802339135017,
#     0.17404174353497684,
#     0.19343255085934696,
#     0.21203441594838043,
#     0.2295153880788771,
#     0.24556351888903633,
#     0.25989242910436355,
#     0.272246418982608,
#     0.28240503128172106,
#     0.290186985324563,
#     0.29545341195688135,
#     0.2981103316706586,
#     0.2981103316706586,
#     0.29545341195688135,
#     0.290186985324563,
#     0.28240503128172106,
#     0.27224641898260804,
#     0.25989242910436355,
#     0.24556351888903635,
#     0.22951538807887717,
#     0.21203441594838046,
#     0.193432550859347,
#     0.17404174353497684,
#     0.15420802339135017,
#     0.13428532363429957,
#     0.11462916531296713,
#     0.09559031303826014,
#     0.07750851558005933,
#     0.060706443042372146,
#     0.04548392880768209,
#     0.032112619003135175,
#     0.02083112496896601,
#     0.01184076523347765,
#     0.005301972979135558,
#     0.0013314331086253094,
#     -2.150912900351522e-33]},
#   'qD5.resonator.const.wf.I': {'type': 'constant', 'sample': 0.125},
#   'qD5.resonator.const.wf.Q': {'type': 'constant', 'sample': 0.0},
#   'qD5.resonator.readout.wf.I': {'type': 'constant',
#    'sample': 0.022213706666666666},
#   'qD5.resonator.readout.wf.Q': {'type': 'constant', 'sample': 0.0},
#   'qD5.z.const.wf': {'type': 'constant', 'sample': 0.1},
#   'qA6.z.Cz_unipolar.flux_pulse_control_qA6.wf': {'type': 'arbitrary',
#    'samples': [0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.06645379340775569,
#     0.0]},
#   'qA6.z.Cz_flat_gaussian.flux_pulse_control_qA6.wf': {'type': 'arbitrary',
#    'samples': [4.794582654738333e-07,
#     4.548973367374389e-06,
#     3.361261940407082e-05,
#     0.00019342726957022812,
#     0.0008668808799382258,
#     0.0030257115742507107,
#     0.008224736790443919,
#     0.01741176792200465,
#     0.02870715213350324,
#     0.03686071298013988,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.038030797612975925,
#     0.03686071298013988,
#     0.02870715213350324,
#     0.01741176792200465,
#     0.008224736790443919,
#     0.0030257115742507107,
#     0.0008668808799382258,
#     0.00019342726957022812,
#     3.361261940407082e-05,
#     4.548973367374389e-06,
#     4.794582654738333e-07]},
#   'qD2.z.Cz_unipolar.flux_pulse_control_qD1.wf': {'type': 'arbitrary',
#    'samples': [2.8491910789212542e-05,
#     0.014759175188118376,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.0322370024128579,
#     0.014759175188118376,
#     2.8491910789212542e-05]}},
#  'digital_waveforms': {'ON': {'samples': [[1, 0]]}},
#  'integration_weights': {'qA1.resonator.readout.iw1': {'cosine': [(0.9897236038163783,
#      1500)],
#    'sine': [(0.14299366436566577, 1500)]},
#   'qA1.resonator.readout.iw2': {'cosine': [(-0.14299366436566577, 1500)],
#    'sine': [(0.9897236038163783, 1500)]},
#   'qA1.resonator.readout.iw3': {'cosine': [(0.14299366436566577, 1500)],
#    'sine': [(-0.9897236038163783, 1500)]},
#   'qA2.resonator.readout.iw1': {'cosine': [(0.9193505604986744, 1500)],
#    'sine': [(-0.39343938149449814, 1500)]},
#   'qA2.resonator.readout.iw2': {'cosine': [(0.39343938149449814, 1500)],
#    'sine': [(0.9193505604986744, 1500)]},
#   'qA2.resonator.readout.iw3': {'cosine': [(-0.39343938149449814, 1500)],
#    'sine': [(-0.9193505604986744, 1500)]},
#   'qA3.resonator.readout.iw1': {'cosine': [(-0.6243808783097137, 1500)],
#    'sine': [(0.7811200412236204, 1500)]},
#   'qA3.resonator.readout.iw2': {'cosine': [(-0.7811200412236204, 1500)],
#    'sine': [(-0.6243808783097137, 1500)]},
#   'qA3.resonator.readout.iw3': {'cosine': [(0.7811200412236204, 1500)],
#    'sine': [(0.6243808783097137, 1500)]},
#   'qA4.resonator.readout.iw1': {'cosine': [(-0.1375061440204268, 1500)],
#    'sine': [(0.9905009138595651, 1500)]},
#   'qA4.resonator.readout.iw2': {'cosine': [(-0.9905009138595651, 1500)],
#    'sine': [(-0.1375061440204268, 1500)]},
#   'qA4.resonator.readout.iw3': {'cosine': [(0.9905009138595651, 1500)],
#    'sine': [(0.1375061440204268, 1500)]},
#   'qA5.resonator.readout.iw1': {'cosine': [(-0.9766142062360947, 1500)],
#    'sine': [(0.21499928413332575, 1500)]},
#   'qA5.resonator.readout.iw2': {'cosine': [(-0.21499928413332575, 1500)],
#    'sine': [(-0.9766142062360947, 1500)]},
#   'qA5.resonator.readout.iw3': {'cosine': [(0.21499928413332575, 1500)],
#    'sine': [(0.9766142062360947, 1500)]},
#   'qA6.resonator.readout.iw1': {'cosine': [(0.5727110904401835, 1500)],
#    'sine': [(-0.8197572853514727, 1500)]},
#   'qA6.resonator.readout.iw2': {'cosine': [(0.8197572853514727, 1500)],
#    'sine': [(0.5727110904401835, 1500)]},
#   'qA6.resonator.readout.iw3': {'cosine': [(-0.8197572853514727, 1500)],
#    'sine': [(-0.5727110904401835, 1500)]},
#   'qB1.resonator.readout.iw1': {'cosine': [(-0.7170828119610476, 1500)],
#    'sine': [(-0.6969879775075297, 1500)]},
#   'qB1.resonator.readout.iw2': {'cosine': [(0.6969879775075297, 1500)],
#    'sine': [(-0.7170828119610476, 1500)]},
#   'qB1.resonator.readout.iw3': {'cosine': [(-0.6969879775075297, 1500)],
#    'sine': [(0.7170828119610476, 1500)]},
#   'qB2.resonator.readout.iw1': {'cosine': [(-0.8195320184874424, 1500)],
#    'sine': [(-0.5730333940303116, 1500)]},
#   'qB2.resonator.readout.iw2': {'cosine': [(0.5730333940303116, 1500)],
#    'sine': [(-0.8195320184874424, 1500)]},
#   'qB2.resonator.readout.iw3': {'cosine': [(-0.5730333940303116, 1500)],
#    'sine': [(0.8195320184874424, 1500)]},
#   'qB3.resonator.readout.iw1': {'cosine': [(0.7260762957935413, 1500)],
#    'sine': [(0.6876141452055288, 1500)]},
#   'qB3.resonator.readout.iw2': {'cosine': [(-0.6876141452055288, 1500)],
#    'sine': [(0.7260762957935413, 1500)]},
#   'qB3.resonator.readout.iw3': {'cosine': [(0.6876141452055288, 1500)],
#    'sine': [(-0.7260762957935413, 1500)]},
#   'qB4.resonator.readout.iw1': {'cosine': [(-0.2604976599478545, 1500)],
#    'sine': [(-0.9654744787728425, 1500)]},
#   'qB4.resonator.readout.iw2': {'cosine': [(0.9654744787728425, 1500)],
#    'sine': [(-0.2604976599478545, 1500)]},
#   'qB4.resonator.readout.iw3': {'cosine': [(-0.9654744787728425, 1500)],
#    'sine': [(0.2604976599478545, 1500)]},
#   'qB5.resonator.readout.iw1': {'cosine': [(0.9420190146285731, 1500)],
#    'sine': [(0.33555949707646826, 1500)]},
#   'qB5.resonator.readout.iw2': {'cosine': [(-0.33555949707646826, 1500)],
#    'sine': [(0.9420190146285731, 1500)]},
#   'qB5.resonator.readout.iw3': {'cosine': [(0.33555949707646826, 1500)],
#    'sine': [(-0.9420190146285731, 1500)]},
#   'qC1.resonator.readout.iw1': {'cosine': [(0.5226859072190242, 1500)],
#    'sine': [(-0.85252533240639, 1500)]},
#   'qC1.resonator.readout.iw2': {'cosine': [(0.85252533240639, 1500)],
#    'sine': [(0.5226859072190242, 1500)]},
#   'qC1.resonator.readout.iw3': {'cosine': [(-0.85252533240639, 1500)],
#    'sine': [(-0.5226859072190242, 1500)]},
#   'qC2.resonator.readout.iw1': {'cosine': [(0.9875399418258888, 1500)],
#    'sine': [(0.15736855879914588, 1500)]},
#   'qC2.resonator.readout.iw2': {'cosine': [(-0.15736855879914588, 1500)],
#    'sine': [(0.9875399418258888, 1500)]},
#   'qC2.resonator.readout.iw3': {'cosine': [(0.15736855879914588, 1500)],
#    'sine': [(-0.9875399418258888, 1500)]},
#   'qC3.resonator.readout.iw1': {'cosine': [(-0.39470857546561045, 1500)],
#    'sine': [(0.9188063672253847, 1500)]},
#   'qC3.resonator.readout.iw2': {'cosine': [(-0.9188063672253847, 1500)],
#    'sine': [(-0.39470857546561045, 1500)]},
#   'qC3.resonator.readout.iw3': {'cosine': [(0.9188063672253847, 1500)],
#    'sine': [(0.39470857546561045, 1500)]},
#   'qC4.resonator.readout.iw1': {'cosine': [(-0.26016355174638894, 1500)],
#    'sine': [(0.9655645635288735, 1500)]},
#   'qC4.resonator.readout.iw2': {'cosine': [(-0.9655645635288735, 1500)],
#    'sine': [(-0.26016355174638894, 1500)]},
#   'qC4.resonator.readout.iw3': {'cosine': [(0.9655645635288735, 1500)],
#    'sine': [(0.26016355174638894, 1500)]},
#   'qC5.resonator.readout.iw1': {'cosine': [(-0.23592116147653247, 1500)],
#    'sine': [(-0.9717721983919708, 1500)]},
#   'qC5.resonator.readout.iw2': {'cosine': [(0.9717721983919708, 1500)],
#    'sine': [(-0.23592116147653247, 1500)]},
#   'qC5.resonator.readout.iw3': {'cosine': [(-0.9717721983919708, 1500)],
#    'sine': [(0.23592116147653247, 1500)]},
#   'qD1.resonator.readout.iw1': {'cosine': [(0.20038385264895386, 1500)],
#    'sine': [(0.9797174651896139, 1500)]},
#   'qD1.resonator.readout.iw2': {'cosine': [(-0.9797174651896139, 1500)],
#    'sine': [(0.20038385264895386, 1500)]},
#   'qD1.resonator.readout.iw3': {'cosine': [(0.9797174651896139, 1500)],
#    'sine': [(-0.20038385264895386, 1500)]},
#   'qD2.resonator.readout.iw1': {'cosine': [(-0.5922983701679803, 1500)],
#    'sine': [(-0.8057187106530134, 1500)]},
#   'qD2.resonator.readout.iw2': {'cosine': [(0.8057187106530134, 1500)],
#    'sine': [(-0.5922983701679803, 1500)]},
#   'qD2.resonator.readout.iw3': {'cosine': [(-0.8057187106530134, 1500)],
#    'sine': [(0.5922983701679803, 1500)]},
#   'qD3.resonator.readout.iw1': {'cosine': [(-0.6784910830582405, 1500)],
#    'sine': [(0.7346086374461275, 1500)]},
#   'qD3.resonator.readout.iw2': {'cosine': [(-0.7346086374461275, 1500)],
#    'sine': [(-0.6784910830582405, 1500)]},
#   'qD3.resonator.readout.iw3': {'cosine': [(0.7346086374461275, 1500)],
#    'sine': [(0.6784910830582405, 1500)]},
#   'qD4.resonator.readout.iw1': {'cosine': [(0.6173035287055675, 2000)],
#    'sine': [(0.7867250812371845, 2000)]},
#   'qD4.resonator.readout.iw2': {'cosine': [(-0.7867250812371845, 2000)],
#    'sine': [(0.6173035287055675, 2000)]},
#   'qD4.resonator.readout.iw3': {'cosine': [(0.7867250812371845, 2000)],
#    'sine': [(-0.6173035287055675, 2000)]},
#   'qD5.resonator.readout.iw1': {'cosine': [(0.06110747466816926, 1500)],
#    'sine': [(-0.9981311920482593, 1500)]},
#   'qD5.resonator.readout.iw2': {'cosine': [(0.9981311920482593, 1500)],
#    'sine': [(0.06110747466816926, 1500)]},
#   'qD5.resonator.readout.iw3': {'cosine': [(-0.9981311920482593, 1500)],
#    'sine': [(-0.06110747466816926, 1500)]}},
#  'mixers': {},
#  'oscillators': {}}

# %%
qc = QuantumCircuit(1)
param = Parameter("param")
qc.rx(param, 0)
qc.measure_all()

param_values = np.linspace(0, np.pi, 10)
transpiled_circuits = transpile(qc, backend)

sampler = QMSamplerV2(backend, options=QMSamplerOptions(input_type=InputType.INPUT_STREAM))
job = sampler.run([(transpiled_circuits, param_values)])
result = job.result()
print(result)
# Out:
# 2025-10-08 12:37:35,040 - qm - WARNING  - Could not generate a loaded config. Maybe there is no `QuantumMachinesManager` instance?
# 2025-10-08 12:37:35 INFO Could not generate a loaded config. Maybe there is no `QuantumMachinesManager` instance?
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/quam/components/channels.py:636: UserWarning: The 'thread' element argument is deprecated from qm.qua >= 1.2.2. Use 'core' instead.
#   warnings.warn(
# [12:37:36] QUA program submitted to arbel (id = 8d5b763a-209a-4883-b4a3-52777e9f3875)              ]8;id=876649;file:///Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/computers.py\computers.py]8;;\:]8;id=473613;file:///Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/computers.py#324\324]8;;\
# [12:38:01] Execution started                                                                       ]8;id=564260;file:///Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/computers.py\computers.py]8;;\:]8;id=64572;file:///Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/computers.py#344\344]8;;\
# [12:38:04] Execution finished                                                                      ]8;id=451365;file:///Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/computers.py\computers.py]8;;\:]8;id=239971;file:///Users/arthurostrauss/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/computers.py#358\358]8;;\
# QUA program has error:
# /app/.venv/lib/python3.11/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning: 'version' is
# deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
#   warnings.warn(
# /app/.venv/lib/python3.11/site-packages/qm/api/v2/qmm_api.py:159: DeprecationWarning: close_other_machines is not
# set, as from 1.3.0 default will be False, now setting to True. Please set it explicitly to remove this message and
# keep the wanted behavior in future versions.
#   warnings.warn(
# /app/temp.py:7800: UserWarning: name 'result_handles' is not defined
#   warnings.warn(str(e))
# /app/temp.py:7805: UserWarning: name 'end_time' is not defined
#   warnings.warn(str(e))
#
#
#  👍     stdout:
#
#  🚨     stderr:
# /app/.venv/lib/python3.11/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning: 'version' is
# deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
#   warnings.warn(
# /app/.venv/lib/python3.11/site-packages/qm/api/v2/qmm_api.py:159: DeprecationWarning: close_other_machines is not
# set, as from 1.3.0 default will be False, now setting to True. Please set it explicitly to remove this message and
# keep the wanted behavior in future versions.
#   warnings.warn(
# /app/temp.py:7800: UserWarning: name 'result_handles' is not defined
#   warnings.warn(str(e))
# /app/temp.py:7805: UserWarning: name 'end_time' is not defined
#   warnings.warn(str(e))
#
#  ⚛️      result
# {}
#  🚀     sync-hook stdout:
#
#  🚀     sync-hook stderr:
# Traceback (most recent call last):
#   File "/app/sync_hook.py", line 2, in <module>
#     from qiskit.qasm3 import loads
# ModuleNotFoundError: No module named 'qiskit'
#
#  🕗 🐍  total Python execution time (s)
# 2.757
#  🕗 ⚛️   QUA execution time (s)
# 0.000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 11
#       9 sampler = QMSamplerV2(backend, options=QMSamplerOptions(input_type=InputType.INPUT_STREAM))
#      10 job = sampler.run([(transpiled_circuits, param_values)])
# ---> 11 result = job.result()
#      12 print(result)
#
# File ~/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/job/qm_sampler_job.py:95, in QMSamplerJob.result(self)
#      93 if self._qm_job is None:
#      94     raise RuntimeError("QM job has not submitted yet")
# ---> 95 return self._result_function(self._qm_job)
#
# File ~/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/job/qm_sampler_job.py:123, in IQCCSamplerJob._result_function(self, qm_job)
#     121 qc_meas_data = {}
#     122 for creg in pub.circuit.cregs:
# --> 123     data = np.array(results_handle.get(f"{creg.name}_{i}")).flatten().tolist()
#     124     bit_array = BitArray.from_samples(data, creg.size).reshape(pub.shape)
#     125     qc_meas_data[creg.name] = bit_array
#
# File ~/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Coding_projects/Quantum_Optimal_Control/.venv/lib/python3.11/site-packages/iqcc_cloud_client/qmm_cloud.py:89, in CloudResultHandles.get(self, handle)
#      88 def get(self, handle: str):
# ---> 89     return CloudResult(self._results_dict[handle])
#
# KeyError: 'meas_0'

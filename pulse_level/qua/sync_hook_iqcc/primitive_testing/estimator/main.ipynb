# %%
from qiskit.circuit import Parameter, QuantumCircuit
from qiskit_qm_provider import IQCCProvider, QMEstimatorV2, QMEstimatorOptions
from qiskit.quantum_info import SparsePauliOp
import numpy as np
from qiskit import transpile

backend = IQCCProvider().get_backend("arbel")
# Out:
# 2025-11-28 09:49:14,791 - qm - INFO     - Starting session: 13350d0c-7f86-4b62-8b15-be3943bc4910
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/backend/flux_tunable_transmon_backend.py:56: UserWarning: qiskit.pulse is not available, channel mapping will not be set.
#   warnings.warn("qiskit.pulse is not available, channel mapping will not be set.")

# %%
qc = QuantumCircuit(1)
param = Parameter("param")
qc.rx(param, 0)
new_qc = transpile(qc, backend=backend)
obs = SparsePauliOp.from_list([("X", 1.2), ("Y", 1.3)]).apply_layout(new_qc.layout)

estimator = QMEstimatorV2(backend=backend, options=QMEstimatorOptions(input_type="INPUT_STREAM"))

job =estimator.run([(new_qc, obs, np.linspace(0, 2*np.pi, 10))])
# Out:
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable param already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_0 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_1 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_2 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_3 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_4 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_5 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_6 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_7 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_8 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_9 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_10 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_11 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_12 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_13 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_14 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_15 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_16 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")
# /Users/arthurostrauss/Library/CloudStorage/OneDrive-QMMachinesLTD/GitHub/qiskit-qm-provider/qiskit_qm_provider/parameter_table/parameter_table.py:236: UserWarning: Variable obs_17 already declared.
#   warnings.warn(f"Variable {parameter.name} already declared.")

# %%
from qm import generate_qua_script
print(generate_qua_script(job.program))
# Out:
# # Single QUA script generated at 2025-11-28 10:45:28.320451
# # QUA library version: 1.2.3.1
#
#
# from qm import CompilerOptionArguments
# from qm.qua import *
#
# with program() as prog:
#     v1 = declare(int, )
#     v2 = declare(int, )
#     v3 = declare(int, )
#     v4 = declare(fixed, value=0.0)
#     v5 = declare(int, value=0)
#     v6 = declare(int, value=0)
#     v7 = declare(int, value=0)
#     v8 = declare(int, value=0)
#     v9 = declare(int, value=0)
#     v10 = declare(int, value=0)
#     v11 = declare(int, value=0)
#     v12 = declare(int, value=0)
#     v13 = declare(int, value=0)
#     v14 = declare(int, value=0)
#     v15 = declare(int, value=0)
#     v16 = declare(int, value=0)
#     v17 = declare(int, value=0)
#     v18 = declare(int, value=0)
#     v19 = declare(int, value=0)
#     v20 = declare(int, value=0)
#     v21 = declare(int, value=0)
#     v22 = declare(int, value=0)
#     a1 = declare(bool, value=[False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False])
#     v23 = declare(int, value=0)
#     v24 = declare(int, value=0)
#     v25 = declare(int, value=0)
#     v26 = declare(int, value=0)
#     v27 = declare(int, value=0)
#     v28 = declare(int, value=0)
#     v29 = declare(int, value=0)
#     v30 = declare(int, value=0)
#     v31 = declare(int, value=0)
#     v32 = declare(int, value=0)
#     v33 = declare(int, value=0)
#     v34 = declare(int, value=0)
#     v35 = declare(int, value=0)
#     v36 = declare(int, value=0)
#     v37 = declare(int, value=0)
#     v38 = declare(int, value=0)
#     v39 = declare(int, value=0)
#     v40 = declare(int, value=0)
#     v41 = declare(fixed, )
#     v42 = declare(fixed, )
#     v43 = declare(bool, )
#     v44 = declare(int, value=1)
#     v45 = declare(fixed, )
#     v46 = declare(fixed, )
#     v47 = declare(bool, )
#     v48 = declare(int, value=1)
#     v49 = declare(fixed, )
#     v50 = declare(fixed, )
#     v51 = declare(bool, )
#     v52 = declare(int, value=1)
#     v53 = declare(fixed, )
#     v54 = declare(fixed, )
#     v55 = declare(bool, )
#     v56 = declare(int, value=1)
#     v57 = declare(fixed, )
#     v58 = declare(fixed, )
#     v59 = declare(bool, )
#     v60 = declare(int, value=1)
#     v61 = declare(fixed, )
#     v62 = declare(fixed, )
#     v63 = declare(bool, )
#     v64 = declare(int, value=1)
#     v65 = declare(fixed, )
#     v66 = declare(fixed, )
#     v67 = declare(bool, )
#     v68 = declare(int, value=1)
#     v69 = declare(fixed, )
#     v70 = declare(fixed, )
#     v71 = declare(bool, )
#     v72 = declare(int, value=1)
#     v73 = declare(fixed, )
#     v74 = declare(fixed, )
#     v75 = declare(bool, )
#     v76 = declare(int, value=1)
#     v77 = declare(fixed, )
#     v78 = declare(fixed, )
#     v79 = declare(bool, )
#     v80 = declare(int, value=1)
#     v81 = declare(fixed, )
#     v82 = declare(fixed, )
#     v83 = declare(bool, )
#     v84 = declare(int, value=1)
#     v85 = declare(fixed, )
#     v86 = declare(fixed, )
#     v87 = declare(bool, )
#     v88 = declare(int, value=1)
#     v89 = declare(fixed, )
#     v90 = declare(fixed, )
#     v91 = declare(bool, )
#     v92 = declare(int, value=1)
#     v93 = declare(fixed, )
#     v94 = declare(fixed, )
#     v95 = declare(bool, )
#     v96 = declare(int, value=1)
#     v97 = declare(fixed, )
#     v98 = declare(fixed, )
#     v99 = declare(bool, )
#     v100 = declare(int, value=1)
#     v101 = declare(fixed, )
#     v102 = declare(fixed, )
#     v103 = declare(bool, )
#     v104 = declare(int, value=1)
#     v105 = declare(fixed, )
#     v106 = declare(fixed, )
#     v107 = declare(bool, )
#     v108 = declare(int, value=1)
#     v109 = declare(fixed, )
#     v110 = declare(fixed, )
#     v111 = declare(bool, )
#     v112 = declare(int, value=1)
#     v113 = declare(bool, )
#     v114 = declare(fixed, )
#     v115 = declare(fixed, )
#     v116 = declare(bool, )
#     v117 = declare(fixed, )
#     v118 = declare(fixed, )
#     v119 = declare(bool, )
#     v120 = declare(fixed, )
#     v121 = declare(fixed, )
#     v122 = declare(bool, )
#     v123 = declare(fixed, )
#     v124 = declare(fixed, )
#     v125 = declare(bool, )
#     v126 = declare(fixed, )
#     v127 = declare(fixed, )
#     v128 = declare(bool, )
#     v129 = declare(fixed, )
#     v130 = declare(fixed, )
#     v131 = declare(bool, )
#     v132 = declare(fixed, )
#     v133 = declare(fixed, )
#     v134 = declare(bool, )
#     v135 = declare(fixed, )
#     v136 = declare(fixed, )
#     v137 = declare(bool, )
#     v138 = declare(fixed, )
#     v139 = declare(fixed, )
#     v140 = declare(bool, )
#     v141 = declare(fixed, )
#     v142 = declare(fixed, )
#     v143 = declare(bool, )
#     v144 = declare(fixed, )
#     v145 = declare(fixed, )
#     v146 = declare(bool, )
#     v147 = declare(fixed, )
#     v148 = declare(fixed, )
#     v149 = declare(bool, )
#     v150 = declare(fixed, )
#     v151 = declare(fixed, )
#     v152 = declare(bool, )
#     v153 = declare(fixed, )
#     v154 = declare(fixed, )
#     v155 = declare(bool, )
#     v156 = declare(fixed, )
#     v157 = declare(fixed, )
#     v158 = declare(bool, )
#     v159 = declare(fixed, )
#     v160 = declare(fixed, )
#     v161 = declare(bool, )
#     v162 = declare(fixed, )
#     v163 = declare(fixed, )
#     v164 = declare(bool, )
#     v165 = declare(fixed, )
#     v166 = declare(fixed, )
#     v167 = declare(int, )
#     set_dc_offset("qA1.z", "single", -0.017431379402432015)
#     set_dc_offset("qA2.z", "single", 0.21385868622846674)
#     set_dc_offset("qA3.z", "single", 0.03514311744487765)
#     set_dc_offset("qA4.z", "single", -0.007590403049357434)
#     set_dc_offset("qA6.z", "single", -0.04360248506335038)
#     set_dc_offset("qB1.z", "single", 0.006028639862824958)
#     set_dc_offset("qB2.z", "single", -0.019101862857346753)
#     set_dc_offset("qB3.z", "single", 0.0055942005482868045)
#     set_dc_offset("qB4.z", "single", 0.02040565700442639)
#     set_dc_offset("qB5.z", "single", -0.04357140262081172)
#     set_dc_offset("qC1.z", "single", 0.014408516703442308)
#     set_dc_offset("qC2.z", "single", 0.008161501390651653)
#     set_dc_offset("qC4.z", "single", -0.003244359436262693)
#     set_dc_offset("qD1.z", "single", -0.03528649869458209)
#     set_dc_offset("qD2.z", "single", -0.041147199395042654)
#     set_dc_offset("qD3.z", "single", -0.04709417313186342)
#     set_dc_offset("qD4.z", "single", -0.00047004557067059584)
#     set_dc_offset("qD5.z", "single", -0.006566530772163777)
#     set_dc_offset("qA5.z", "single", 0.0)
#     set_dc_offset("qC3.z", "single", 0.0)
#     set_dc_offset("qC5.z", "single", 0.0)
#     with for_(v1,0,(v1<10),(v1+1)):
#         advance_input_stream(input_stream_param)
#         with for_(v2,0,(v2<20),(v2+1)):
#             advance_input_stream(input_stream_obs_0)
#             advance_input_stream(input_stream_obs_1)
#             advance_input_stream(input_stream_obs_2)
#             advance_input_stream(input_stream_obs_3)
#             advance_input_stream(input_stream_obs_4)
#             advance_input_stream(input_stream_obs_5)
#             advance_input_stream(input_stream_obs_6)
#             advance_input_stream(input_stream_obs_7)
#             advance_input_stream(input_stream_obs_8)
#             advance_input_stream(input_stream_obs_9)
#             advance_input_stream(input_stream_obs_10)
#             advance_input_stream(input_stream_obs_11)
#             advance_input_stream(input_stream_obs_12)
#             advance_input_stream(input_stream_obs_13)
#             advance_input_stream(input_stream_obs_14)
#             advance_input_stream(input_stream_obs_15)
#             advance_input_stream(input_stream_obs_16)
#             advance_input_stream(input_stream_obs_17)
#             with for_(v3,0,(v3<4096),(v3+1)):
#                 assign(v4, input_stream_param)
#                 assign(v5, input_stream_obs_0)
#                 assign(v6, input_stream_obs_1)
#                 assign(v7, input_stream_obs_2)
#                 assign(v8, input_stream_obs_3)
#                 assign(v9, input_stream_obs_4)
#                 assign(v10, input_stream_obs_5)
#                 assign(v11, input_stream_obs_6)
#                 assign(v12, input_stream_obs_7)
#                 assign(v13, input_stream_obs_8)
#                 assign(v14, input_stream_obs_9)
#                 assign(v15, input_stream_obs_10)
#                 assign(v16, input_stream_obs_11)
#                 assign(v17, input_stream_obs_12)
#                 assign(v18, input_stream_obs_13)
#                 assign(v19, input_stream_obs_14)
#                 assign(v20, input_stream_obs_15)
#                 assign(v21, input_stream_obs_16)
#                 assign(v22, input_stream_obs_17)
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 assign(v44, 1)
#                 align("qA1.resonator", "qA1.xy")
#                 measure("readout", "qA1.resonator", dual_demod.full("iw1", "iw2", v41), dual_demod.full("iw3", "iw1", v42))
#                 assign(v43, (v41>0.00025058940111762827))
#                 wait(750, "qA1.resonator")
#                 align("qA1.resonator", "qA1.xy")
#                 play("x180_DragCosine", "qA1.xy", condition=v43)
#                 align("qA1.resonator", "qA1.xy")
#                 with while_(broadcast.and_((v41>0.00012382043733943533), (v44<5))):
#                     align("qA1.resonator", "qA1.xy")
#                     measure("readout", "qA1.resonator", dual_demod.full("iw1", "iw2", v41), dual_demod.full("iw3", "iw1", v42))
#                     assign(v43, (v41>0.00025058940111762827))
#                     wait(750, "qA1.resonator")
#                     align("qA1.resonator", "qA1.xy")
#                     play("x180_DragCosine", "qA1.xy", condition=v43)
#                     align("qA1.resonator", "qA1.xy")
#                     assign(v44, (v44+1))
#                 align("qA1.resonator", "qA1.xy")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 align("qA2.resonator", "qA2.xy", "qA2.z")
#                 assign(v48, 1)
#                 align("qA2.resonator", "qA2.xy")
#                 measure("readout", "qA2.resonator", dual_demod.full("iw1", "iw2", v45), dual_demod.full("iw3", "iw1", v46))
#                 assign(v47, (v45>7.78737836462102e-05))
#                 wait(750, "qA2.resonator")
#                 align("qA2.resonator", "qA2.xy")
#                 play("x180_DragCosine", "qA2.xy", condition=v47)
#                 align("qA2.resonator", "qA2.xy")
#                 with while_(broadcast.and_((v45>0.00014440671389515442), (v48<5))):
#                     align("qA2.resonator", "qA2.xy")
#                     measure("readout", "qA2.resonator", dual_demod.full("iw1", "iw2", v45), dual_demod.full("iw3", "iw1", v46))
#                     assign(v47, (v45>7.78737836462102e-05))
#                     wait(750, "qA2.resonator")
#                     align("qA2.resonator", "qA2.xy")
#                     play("x180_DragCosine", "qA2.xy", condition=v47)
#                     align("qA2.resonator", "qA2.xy")
#                     assign(v48, (v48+1))
#                 align("qA2.resonator", "qA2.xy")
#                 align("qA2.resonator", "qA2.xy", "qA2.z")
#                 align("qA3.resonator", "qA3.xy", "qA3.z")
#                 assign(v52, 1)
#                 align("qA3.resonator", "qA3.xy")
#                 measure("readout", "qA3.resonator", dual_demod.full("iw1", "iw2", v49), dual_demod.full("iw3", "iw1", v50))
#                 assign(v51, (v49>0.000749019874730219))
#                 wait(750, "qA3.resonator")
#                 align("qA3.resonator", "qA3.xy")
#                 play("x180_DragCosine", "qA3.xy", condition=v51)
#                 align("qA3.resonator", "qA3.xy")
#                 with while_(broadcast.and_((v49>0.0004510498642764791), (v52<5))):
#                     align("qA3.resonator", "qA3.xy")
#                     measure("readout", "qA3.resonator", dual_demod.full("iw1", "iw2", v49), dual_demod.full("iw3", "iw1", v50))
#                     assign(v51, (v49>0.000749019874730219))
#                     wait(750, "qA3.resonator")
#                     align("qA3.resonator", "qA3.xy")
#                     play("x180_DragCosine", "qA3.xy", condition=v51)
#                     align("qA3.resonator", "qA3.xy")
#                     assign(v52, (v52+1))
#                 align("qA3.resonator", "qA3.xy")
#                 align("qA3.resonator", "qA3.xy", "qA3.z")
#                 align("qA4.resonator", "qA4.xy", "qA4.z")
#                 assign(v56, 1)
#                 align("qA4.resonator", "qA4.xy")
#                 measure("readout", "qA4.resonator", dual_demod.full("iw1", "iw2", v53), dual_demod.full("iw3", "iw1", v54))
#                 assign(v55, (v53>-0.00014449193999423478))
#                 wait(750, "qA4.resonator")
#                 align("qA4.resonator", "qA4.xy")
#                 play("x180_DragCosine", "qA4.xy", condition=v55)
#                 align("qA4.resonator", "qA4.xy")
#                 with while_(broadcast.and_((v53>-9.770967750827104e-05), (v56<5))):
#                     align("qA4.resonator", "qA4.xy")
#                     measure("readout", "qA4.resonator", dual_demod.full("iw1", "iw2", v53), dual_demod.full("iw3", "iw1", v54))
#                     assign(v55, (v53>-0.00014449193999423478))
#                     wait(750, "qA4.resonator")
#                     align("qA4.resonator", "qA4.xy")
#                     play("x180_DragCosine", "qA4.xy", condition=v55)
#                     align("qA4.resonator", "qA4.xy")
#                     assign(v56, (v56+1))
#                 align("qA4.resonator", "qA4.xy")
#                 align("qA4.resonator", "qA4.xy", "qA4.z")
#                 align("qA6.resonator", "qA6.xy", "qA6.z")
#                 assign(v60, 1)
#                 align("qA6.resonator", "qA6.xy")
#                 measure("readout", "qA6.resonator", dual_demod.full("iw1", "iw2", v57), dual_demod.full("iw3", "iw1", v58))
#                 assign(v59, (v57>0.0008141418019060033))
#                 wait(750, "qA6.resonator")
#                 align("qA6.resonator", "qA6.xy")
#                 play("x180_DragCosine", "qA6.xy", condition=v59)
#                 align("qA6.resonator", "qA6.xy")
#                 with while_(broadcast.and_((v57>0.00033100179671903453), (v60<5))):
#                     align("qA6.resonator", "qA6.xy")
#                     measure("readout", "qA6.resonator", dual_demod.full("iw1", "iw2", v57), dual_demod.full("iw3", "iw1", v58))
#                     assign(v59, (v57>0.0008141418019060033))
#                     wait(750, "qA6.resonator")
#                     align("qA6.resonator", "qA6.xy")
#                     play("x180_DragCosine", "qA6.xy", condition=v59)
#                     align("qA6.resonator", "qA6.xy")
#                     assign(v60, (v60+1))
#                 align("qA6.resonator", "qA6.xy")
#                 align("qA6.resonator", "qA6.xy", "qA6.z")
#                 align("qB1.resonator", "qB1.xy", "qB1.z")
#                 assign(v64, 1)
#                 align("qB1.resonator", "qB1.xy")
#                 measure("readout", "qB1.resonator", dual_demod.full("iw1", "iw2", v61), dual_demod.full("iw3", "iw1", v62))
#                 assign(v63, (v61>0.0012358176158358415))
#                 wait(750, "qB1.resonator")
#                 align("qB1.resonator", "qB1.xy")
#                 play("x180_DragCosine", "qB1.xy", condition=v63)
#                 align("qB1.resonator", "qB1.xy")
#                 with while_(broadcast.and_((v61>0.0005363885005700566), (v64<5))):
#                     align("qB1.resonator", "qB1.xy")
#                     measure("readout", "qB1.resonator", dual_demod.full("iw1", "iw2", v61), dual_demod.full("iw3", "iw1", v62))
#                     assign(v63, (v61>0.0012358176158358415))
#                     wait(750, "qB1.resonator")
#                     align("qB1.resonator", "qB1.xy")
#                     play("x180_DragCosine", "qB1.xy", condition=v63)
#                     align("qB1.resonator", "qB1.xy")
#                     assign(v64, (v64+1))
#                 align("qB1.resonator", "qB1.xy")
#                 align("qB1.resonator", "qB1.xy", "qB1.z")
#                 align("qB2.resonator", "qB2.xy", "qB2.z")
#                 assign(v68, 1)
#                 align("qB2.resonator", "qB2.xy")
#                 measure("readout", "qB2.resonator", dual_demod.full("iw1", "iw2", v65), dual_demod.full("iw3", "iw1", v66))
#                 assign(v67, (v65>0.0012232037284515098))
#                 wait(750, "qB2.resonator")
#                 align("qB2.resonator", "qB2.xy")
#                 play("x180_DragCosine", "qB2.xy", condition=v67)
#                 align("qB2.resonator", "qB2.xy")
#                 with while_(broadcast.and_((v65>0.0003990683755599683), (v68<5))):
#                     align("qB2.resonator", "qB2.xy")
#                     measure("readout", "qB2.resonator", dual_demod.full("iw1", "iw2", v65), dual_demod.full("iw3", "iw1", v66))
#                     assign(v67, (v65>0.0012232037284515098))
#                     wait(750, "qB2.resonator")
#                     align("qB2.resonator", "qB2.xy")
#                     play("x180_DragCosine", "qB2.xy", condition=v67)
#                     align("qB2.resonator", "qB2.xy")
#                     assign(v68, (v68+1))
#                 align("qB2.resonator", "qB2.xy")
#                 align("qB2.resonator", "qB2.xy", "qB2.z")
#                 align("qB3.resonator", "qB3.xy", "qB3.z")
#                 assign(v72, 1)
#                 align("qB3.resonator", "qB3.xy")
#                 measure("readout", "qB3.resonator", dual_demod.full("iw1", "iw2", v69), dual_demod.full("iw3", "iw1", v70))
#                 assign(v71, (v69>0.0012403000540539956))
#                 wait(750, "qB3.resonator")
#                 align("qB3.resonator", "qB3.xy")
#                 play("x180_DragCosine", "qB3.xy", condition=v71)
#                 align("qB3.resonator", "qB3.xy")
#                 with while_(broadcast.and_((v69>0.001089931452951197), (v72<5))):
#                     align("qB3.resonator", "qB3.xy")
#                     measure("readout", "qB3.resonator", dual_demod.full("iw1", "iw2", v69), dual_demod.full("iw3", "iw1", v70))
#                     assign(v71, (v69>0.0012403000540539956))
#                     wait(750, "qB3.resonator")
#                     align("qB3.resonator", "qB3.xy")
#                     play("x180_DragCosine", "qB3.xy", condition=v71)
#                     align("qB3.resonator", "qB3.xy")
#                     assign(v72, (v72+1))
#                 align("qB3.resonator", "qB3.xy")
#                 align("qB3.resonator", "qB3.xy", "qB3.z")
#                 align("qB4.resonator", "qB4.xy", "qB4.z")
#                 assign(v76, 1)
#                 align("qB4.resonator", "qB4.xy")
#                 measure("readout", "qB4.resonator", dual_demod.full("iw1", "iw2", v73), dual_demod.full("iw3", "iw1", v74))
#                 assign(v75, (v73>0.0012071295676076435))
#                 wait(750, "qB4.resonator")
#                 align("qB4.resonator", "qB4.xy")
#                 play("x180_DragCosine", "qB4.xy", condition=v75)
#                 align("qB4.resonator", "qB4.xy")
#                 with while_(broadcast.and_((v73>0.0009105549333574925), (v76<5))):
#                     align("qB4.resonator", "qB4.xy")
#                     measure("readout", "qB4.resonator", dual_demod.full("iw1", "iw2", v73), dual_demod.full("iw3", "iw1", v74))
#                     assign(v75, (v73>0.0012071295676076435))
#                     wait(750, "qB4.resonator")
#                     align("qB4.resonator", "qB4.xy")
#                     play("x180_DragCosine", "qB4.xy", condition=v75)
#                     align("qB4.resonator", "qB4.xy")
#                     assign(v76, (v76+1))
#                 align("qB4.resonator", "qB4.xy")
#                 align("qB4.resonator", "qB4.xy", "qB4.z")
#                 align("qB5.resonator", "qB5.xy", "qB5.z")
#                 assign(v80, 1)
#                 align("qB5.resonator", "qB5.xy")
#                 measure("readout", "qB5.resonator", dual_demod.full("iw1", "iw2", v77), dual_demod.full("iw3", "iw1", v78))
#                 assign(v79, (v77>0.0023589081316441546))
#                 wait(750, "qB5.resonator")
#                 align("qB5.resonator", "qB5.xy")
#                 play("x180_DragCosine", "qB5.xy", condition=v79)
#                 align("qB5.resonator", "qB5.xy")
#                 with while_(broadcast.and_((v77>0.0019752487235446025), (v80<5))):
#                     align("qB5.resonator", "qB5.xy")
#                     measure("readout", "qB5.resonator", dual_demod.full("iw1", "iw2", v77), dual_demod.full("iw3", "iw1", v78))
#                     assign(v79, (v77>0.0023589081316441546))
#                     wait(750, "qB5.resonator")
#                     align("qB5.resonator", "qB5.xy")
#                     play("x180_DragCosine", "qB5.xy", condition=v79)
#                     align("qB5.resonator", "qB5.xy")
#                     assign(v80, (v80+1))
#                 align("qB5.resonator", "qB5.xy")
#                 align("qB5.resonator", "qB5.xy", "qB5.z")
#                 align("qC1.resonator", "qC1.xy", "qC1.z")
#                 assign(v84, 1)
#                 align("qC1.resonator", "qC1.xy")
#                 measure("readout", "qC1.resonator", dual_demod.full("iw1", "iw2", v81), dual_demod.full("iw3", "iw1", v82))
#                 assign(v83, (v81>0.00014968677947712738))
#                 wait(750, "qC1.resonator")
#                 align("qC1.resonator", "qC1.xy")
#                 play("x180_DragCosine", "qC1.xy", condition=v83)
#                 align("qC1.resonator", "qC1.xy")
#                 with while_(broadcast.and_((v81>7.212897064209038e-05), (v84<5))):
#                     align("qC1.resonator", "qC1.xy")
#                     measure("readout", "qC1.resonator", dual_demod.full("iw1", "iw2", v81), dual_demod.full("iw3", "iw1", v82))
#                     assign(v83, (v81>0.00014968677947712738))
#                     wait(750, "qC1.resonator")
#                     align("qC1.resonator", "qC1.xy")
#                     play("x180_DragCosine", "qC1.xy", condition=v83)
#                     align("qC1.resonator", "qC1.xy")
#                     assign(v84, (v84+1))
#                 align("qC1.resonator", "qC1.xy")
#                 align("qC1.resonator", "qC1.xy", "qC1.z")
#                 align("qC2.resonator", "qC2.xy", "qC2.z")
#                 assign(v88, 1)
#                 align("qC2.resonator", "qC2.xy")
#                 measure("readout", "qC2.resonator", dual_demod.full("iw1", "iw2", v85), dual_demod.full("iw3", "iw1", v86))
#                 assign(v87, (v85>0.00016926329503889285))
#                 wait(750, "qC2.resonator")
#                 align("qC2.resonator", "qC2.xy")
#                 play("x180_DragCosine", "qC2.xy", condition=v87)
#                 align("qC2.resonator", "qC2.xy")
#                 with while_(broadcast.and_((v85>6.311545965417149e-05), (v88<5))):
#                     align("qC2.resonator", "qC2.xy")
#                     measure("readout", "qC2.resonator", dual_demod.full("iw1", "iw2", v85), dual_demod.full("iw3", "iw1", v86))
#                     assign(v87, (v85>0.00016926329503889285))
#                     wait(750, "qC2.resonator")
#                     align("qC2.resonator", "qC2.xy")
#                     play("x180_DragCosine", "qC2.xy", condition=v87)
#                     align("qC2.resonator", "qC2.xy")
#                     assign(v88, (v88+1))
#                 align("qC2.resonator", "qC2.xy")
#                 align("qC2.resonator", "qC2.xy", "qC2.z")
#                 align("qC4.resonator", "qC4.xy", "qC4.z")
#                 assign(v92, 1)
#                 align("qC4.resonator", "qC4.xy")
#                 measure("readout", "qC4.resonator", dual_demod.full("iw1", "iw2", v89), dual_demod.full("iw3", "iw1", v90))
#                 assign(v91, (v89>0.0002390371513853697))
#                 wait(750, "qC4.resonator")
#                 align("qC4.resonator", "qC4.xy")
#                 play("x180_DragCosine", "qC4.xy", condition=v91)
#                 align("qC4.resonator", "qC4.xy")
#                 with while_(broadcast.and_((v89>0.00018225343318408157), (v92<5))):
#                     align("qC4.resonator", "qC4.xy")
#                     measure("readout", "qC4.resonator", dual_demod.full("iw1", "iw2", v89), dual_demod.full("iw3", "iw1", v90))
#                     assign(v91, (v89>0.0002390371513853697))
#                     wait(750, "qC4.resonator")
#                     align("qC4.resonator", "qC4.xy")
#                     play("x180_DragCosine", "qC4.xy", condition=v91)
#                     align("qC4.resonator", "qC4.xy")
#                     assign(v92, (v92+1))
#                 align("qC4.resonator", "qC4.xy")
#                 align("qC4.resonator", "qC4.xy", "qC4.z")
#                 align("qD1.resonator", "qD1.xy", "qD1.z")
#                 assign(v96, 1)
#                 align("qD1.resonator", "qD1.xy")
#                 measure("readout", "qD1.resonator", dual_demod.full("iw1", "iw2", v93), dual_demod.full("iw3", "iw1", v94))
#                 assign(v95, (v93>0.0006627114274709664))
#                 wait(750, "qD1.resonator")
#                 align("qD1.resonator", "qD1.xy")
#                 play("x180_DragCosine", "qD1.xy", condition=v95)
#                 align("qD1.resonator", "qD1.xy")
#                 with while_(broadcast.and_((v93>0.00040039277367452013), (v96<5))):
#                     align("qD1.resonator", "qD1.xy")
#                     measure("readout", "qD1.resonator", dual_demod.full("iw1", "iw2", v93), dual_demod.full("iw3", "iw1", v94))
#                     assign(v95, (v93>0.0006627114274709664))
#                     wait(750, "qD1.resonator")
#                     align("qD1.resonator", "qD1.xy")
#                     play("x180_DragCosine", "qD1.xy", condition=v95)
#                     align("qD1.resonator", "qD1.xy")
#                     assign(v96, (v96+1))
#                 align("qD1.resonator", "qD1.xy")
#                 align("qD1.resonator", "qD1.xy", "qD1.z")
#                 align("qD2.resonator", "qD2.xy", "qD2.z")
#                 assign(v100, 1)
#                 align("qD2.resonator", "qD2.xy")
#                 measure("readout", "qD2.resonator", dual_demod.full("iw1", "iw2", v97), dual_demod.full("iw3", "iw1", v98))
#                 assign(v99, (v97>0.0008867118558507442))
#                 wait(750, "qD2.resonator")
#                 align("qD2.resonator", "qD2.xy")
#                 play("x180_DragCosine", "qD2.xy", condition=v99)
#                 align("qD2.resonator", "qD2.xy")
#                 with while_(broadcast.and_((v97>0.0005353878269192669), (v100<5))):
#                     align("qD2.resonator", "qD2.xy")
#                     measure("readout", "qD2.resonator", dual_demod.full("iw1", "iw2", v97), dual_demod.full("iw3", "iw1", v98))
#                     assign(v99, (v97>0.0008867118558507442))
#                     wait(750, "qD2.resonator")
#                     align("qD2.resonator", "qD2.xy")
#                     play("x180_DragCosine", "qD2.xy", condition=v99)
#                     align("qD2.resonator", "qD2.xy")
#                     assign(v100, (v100+1))
#                 align("qD2.resonator", "qD2.xy")
#                 align("qD2.resonator", "qD2.xy", "qD2.z")
#                 align("qD3.resonator", "qD3.xy", "qD3.z")
#                 assign(v104, 1)
#                 align("qD3.resonator", "qD3.xy")
#                 measure("readout", "qD3.resonator", dual_demod.full("iw1", "iw2", v101), dual_demod.full("iw3", "iw1", v102))
#                 assign(v103, (v101>0.0008193751879293711))
#                 wait(750, "qD3.resonator")
#                 align("qD3.resonator", "qD3.xy")
#                 play("x180_DragCosine", "qD3.xy", condition=v103)
#                 align("qD3.resonator", "qD3.xy")
#                 with while_(broadcast.and_((v101>0.0007101080940949191), (v104<5))):
#                     align("qD3.resonator", "qD3.xy")
#                     measure("readout", "qD3.resonator", dual_demod.full("iw1", "iw2", v101), dual_demod.full("iw3", "iw1", v102))
#                     assign(v103, (v101>0.0008193751879293711))
#                     wait(750, "qD3.resonator")
#                     align("qD3.resonator", "qD3.xy")
#                     play("x180_DragCosine", "qD3.xy", condition=v103)
#                     align("qD3.resonator", "qD3.xy")
#                     assign(v104, (v104+1))
#                 align("qD3.resonator", "qD3.xy")
#                 align("qD3.resonator", "qD3.xy", "qD3.z")
#                 align("qD4.resonator", "qD4.xy", "qD4.z")
#                 assign(v108, 1)
#                 align("qD4.resonator", "qD4.xy")
#                 measure("readout", "qD4.resonator", dual_demod.full("iw1", "iw2", v105), dual_demod.full("iw3", "iw1", v106))
#                 assign(v107, (v105>0.0009560861598610923))
#                 wait(750, "qD4.resonator")
#                 align("qD4.resonator", "qD4.xy")
#                 play("x180_DragCosine", "qD4.xy", condition=v107)
#                 align("qD4.resonator", "qD4.xy")
#                 with while_(broadcast.and_((v105>0.0006813907989205732), (v108<5))):
#                     align("qD4.resonator", "qD4.xy")
#                     measure("readout", "qD4.resonator", dual_demod.full("iw1", "iw2", v105), dual_demod.full("iw3", "iw1", v106))
#                     assign(v107, (v105>0.0009560861598610923))
#                     wait(750, "qD4.resonator")
#                     align("qD4.resonator", "qD4.xy")
#                     play("x180_DragCosine", "qD4.xy", condition=v107)
#                     align("qD4.resonator", "qD4.xy")
#                     assign(v108, (v108+1))
#                 align("qD4.resonator", "qD4.xy")
#                 align("qD4.resonator", "qD4.xy", "qD4.z")
#                 align("qD5.resonator", "qD5.xy", "qD5.z")
#                 assign(v112, 1)
#                 align("qD5.resonator", "qD5.xy")
#                 measure("readout", "qD5.resonator", dual_demod.full("iw1", "iw2", v109), dual_demod.full("iw3", "iw1", v110))
#                 assign(v111, (v109>0.0006576820851857754))
#                 wait(750, "qD5.resonator")
#                 align("qD5.resonator", "qD5.xy")
#                 play("x180_DragCosine", "qD5.xy", condition=v111)
#                 align("qD5.resonator", "qD5.xy")
#                 with while_(broadcast.and_((v109>0.00046596138175736225), (v112<5))):
#                     align("qD5.resonator", "qD5.xy")
#                     measure("readout", "qD5.resonator", dual_demod.full("iw1", "iw2", v109), dual_demod.full("iw3", "iw1", v110))
#                     assign(v111, (v109>0.0006576820851857754))
#                     wait(750, "qD5.resonator")
#                     align("qD5.resonator", "qD5.xy")
#                     play("x180_DragCosine", "qD5.xy", condition=v111)
#                     align("qD5.resonator", "qD5.xy")
#                     assign(v112, (v112+1))
#                 align("qD5.resonator", "qD5.xy")
#                 align("qD5.resonator", "qD5.xy", "qD5.z")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 frame_rotation_2pi(-0.25, "qA1.xy")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 play("x90_DragCosine", "qA1.xy")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 frame_rotation_2pi(((0.0-(3.141592653589793+v4))*0.15915494309189535), "qA1.xy")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 play("x90_DragCosine", "qA1.xy")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 frame_rotation_2pi(-1.25, "qA1.xy")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 assign(v23, v5)
#                 with if_((v23==1)):
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     frame_rotation_2pi(-0.25, "qA1.xy")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     play("x90_DragCosine", "qA1.xy")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     frame_rotation_2pi(-0.25, "qA1.xy")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                 with elif_((v23==2)):
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     play("x90_DragCosine", "qA1.xy")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                     frame_rotation_2pi(-0.25, "qA1.xy")
#                     align("qA1.resonator", "qA1.xy", "qA1.z")
#                 assign(v24, v6)
#                 with if_((v24==1)):
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     frame_rotation_2pi(-0.25, "qA2.xy")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     play("x90_DragCosine", "qA2.xy")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     frame_rotation_2pi(-0.25, "qA2.xy")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                 with elif_((v24==2)):
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     play("x90_DragCosine", "qA2.xy")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                     frame_rotation_2pi(-0.25, "qA2.xy")
#                     align("qA2.resonator", "qA2.xy", "qA2.z")
#                 assign(v25, v7)
#                 with if_((v25==1)):
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     frame_rotation_2pi(-0.25, "qA3.xy")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     play("x90_DragCosine", "qA3.xy")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     frame_rotation_2pi(-0.25, "qA3.xy")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                 with elif_((v25==2)):
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     play("x90_DragCosine", "qA3.xy")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                     frame_rotation_2pi(-0.25, "qA3.xy")
#                     align("qA3.resonator", "qA3.xy", "qA3.z")
#                 assign(v26, v8)
#                 with if_((v26==1)):
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     frame_rotation_2pi(-0.25, "qA4.xy")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     play("x90_DragCosine", "qA4.xy")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     frame_rotation_2pi(-0.25, "qA4.xy")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                 with elif_((v26==2)):
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     play("x90_DragCosine", "qA4.xy")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                     frame_rotation_2pi(-0.25, "qA4.xy")
#                     align("qA4.resonator", "qA4.xy", "qA4.z")
#                 assign(v27, v9)
#                 with if_((v27==1)):
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     frame_rotation_2pi(-0.25, "qA6.xy")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     play("x90_DragCosine", "qA6.xy")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     frame_rotation_2pi(-0.25, "qA6.xy")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                 with elif_((v27==2)):
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     play("x90_DragCosine", "qA6.xy")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                     frame_rotation_2pi(-0.25, "qA6.xy")
#                     align("qA6.resonator", "qA6.xy", "qA6.z")
#                 assign(v28, v10)
#                 with if_((v28==1)):
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     frame_rotation_2pi(-0.25, "qB1.xy")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     play("x90_DragCosine", "qB1.xy")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     frame_rotation_2pi(-0.25, "qB1.xy")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                 with elif_((v28==2)):
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     play("x90_DragCosine", "qB1.xy")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                     frame_rotation_2pi(-0.25, "qB1.xy")
#                     align("qB1.resonator", "qB1.xy", "qB1.z")
#                 assign(v29, v11)
#                 with if_((v29==1)):
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     frame_rotation_2pi(-0.25, "qB2.xy")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     play("x90_DragCosine", "qB2.xy")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     frame_rotation_2pi(-0.25, "qB2.xy")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                 with elif_((v29==2)):
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     play("x90_DragCosine", "qB2.xy")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                     frame_rotation_2pi(-0.25, "qB2.xy")
#                     align("qB2.resonator", "qB2.xy", "qB2.z")
#                 assign(v30, v12)
#                 with if_((v30==1)):
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     frame_rotation_2pi(-0.25, "qB3.xy")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     play("x90_DragCosine", "qB3.xy")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     frame_rotation_2pi(-0.25, "qB3.xy")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                 with elif_((v30==2)):
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     play("x90_DragCosine", "qB3.xy")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                     frame_rotation_2pi(-0.25, "qB3.xy")
#                     align("qB3.resonator", "qB3.xy", "qB3.z")
#                 assign(v31, v13)
#                 with if_((v31==1)):
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     frame_rotation_2pi(-0.25, "qB4.xy")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     play("x90_DragCosine", "qB4.xy")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     frame_rotation_2pi(-0.25, "qB4.xy")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                 with elif_((v31==2)):
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     play("x90_DragCosine", "qB4.xy")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                     frame_rotation_2pi(-0.25, "qB4.xy")
#                     align("qB4.resonator", "qB4.xy", "qB4.z")
#                 assign(v32, v14)
#                 with if_((v32==1)):
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     frame_rotation_2pi(-0.25, "qB5.xy")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     play("x90_DragCosine", "qB5.xy")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     frame_rotation_2pi(-0.25, "qB5.xy")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                 with elif_((v32==2)):
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     play("x90_DragCosine", "qB5.xy")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                     frame_rotation_2pi(-0.25, "qB5.xy")
#                     align("qB5.resonator", "qB5.xy", "qB5.z")
#                 assign(v33, v15)
#                 with if_((v33==1)):
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     frame_rotation_2pi(-0.25, "qC1.xy")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     play("x90_DragCosine", "qC1.xy")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     frame_rotation_2pi(-0.25, "qC1.xy")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                 with elif_((v33==2)):
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     play("x90_DragCosine", "qC1.xy")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                     frame_rotation_2pi(-0.25, "qC1.xy")
#                     align("qC1.resonator", "qC1.xy", "qC1.z")
#                 assign(v34, v16)
#                 with if_((v34==1)):
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     frame_rotation_2pi(-0.25, "qC2.xy")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     play("x90_DragCosine", "qC2.xy")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     frame_rotation_2pi(-0.25, "qC2.xy")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                 with elif_((v34==2)):
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     play("x90_DragCosine", "qC2.xy")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                     frame_rotation_2pi(-0.25, "qC2.xy")
#                     align("qC2.resonator", "qC2.xy", "qC2.z")
#                 assign(v35, v17)
#                 with if_((v35==1)):
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     frame_rotation_2pi(-0.25, "qC4.xy")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     play("x90_DragCosine", "qC4.xy")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     frame_rotation_2pi(-0.25, "qC4.xy")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                 with elif_((v35==2)):
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     play("x90_DragCosine", "qC4.xy")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                     frame_rotation_2pi(-0.25, "qC4.xy")
#                     align("qC4.resonator", "qC4.xy", "qC4.z")
#                 assign(v36, v18)
#                 with if_((v36==1)):
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     frame_rotation_2pi(-0.25, "qD1.xy")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     play("x90_DragCosine", "qD1.xy")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     frame_rotation_2pi(-0.25, "qD1.xy")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                 with elif_((v36==2)):
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     play("x90_DragCosine", "qD1.xy")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                     frame_rotation_2pi(-0.25, "qD1.xy")
#                     align("qD1.resonator", "qD1.xy", "qD1.z")
#                 assign(v37, v19)
#                 with if_((v37==1)):
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     frame_rotation_2pi(-0.25, "qD2.xy")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     play("x90_DragCosine", "qD2.xy")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     frame_rotation_2pi(-0.25, "qD2.xy")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                 with elif_((v37==2)):
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     play("x90_DragCosine", "qD2.xy")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                     frame_rotation_2pi(-0.25, "qD2.xy")
#                     align("qD2.resonator", "qD2.xy", "qD2.z")
#                 assign(v38, v20)
#                 with if_((v38==1)):
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     frame_rotation_2pi(-0.25, "qD3.xy")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     play("x90_DragCosine", "qD3.xy")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     frame_rotation_2pi(-0.25, "qD3.xy")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                 with elif_((v38==2)):
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     play("x90_DragCosine", "qD3.xy")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                     frame_rotation_2pi(-0.25, "qD3.xy")
#                     align("qD3.resonator", "qD3.xy", "qD3.z")
#                 assign(v39, v21)
#                 with if_((v39==1)):
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     frame_rotation_2pi(-0.25, "qD4.xy")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     play("x90_DragCosine", "qD4.xy")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     frame_rotation_2pi(-0.25, "qD4.xy")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                 with elif_((v39==2)):
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     play("x90_DragCosine", "qD4.xy")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                     frame_rotation_2pi(-0.25, "qD4.xy")
#                     align("qD4.resonator", "qD4.xy", "qD4.z")
#                 assign(v40, v22)
#                 with if_((v40==1)):
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     frame_rotation_2pi(-0.25, "qD5.xy")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     play("x90_DragCosine", "qD5.xy")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     frame_rotation_2pi(-0.25, "qD5.xy")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                 with elif_((v40==2)):
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     play("x90_DragCosine", "qD5.xy")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                     frame_rotation_2pi(-0.25, "qD5.xy")
#                     align("qD5.resonator", "qD5.xy", "qD5.z")
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 measure("readout", "qA1.resonator", dual_demod.full("iw1", "iw2", v114), dual_demod.full("iw3", "iw1", v115))
#                 assign(v113, (v114>0.00025058940111762827))
#                 align("qA1.resonator", "qA1.xy", "qA1.z")
#                 assign(a1[0], v113)
#                 align("qA2.resonator", "qA2.xy", "qA2.z")
#                 measure("readout", "qA2.resonator", dual_demod.full("iw1", "iw2", v117), dual_demod.full("iw3", "iw1", v118))
#                 assign(v116, (v117>7.78737836462102e-05))
#                 align("qA2.resonator", "qA2.xy", "qA2.z")
#                 assign(a1[1], v116)
#                 align("qA3.resonator", "qA3.xy", "qA3.z")
#                 measure("readout", "qA3.resonator", dual_demod.full("iw1", "iw2", v120), dual_demod.full("iw3", "iw1", v121))
#                 assign(v119, (v120>0.000749019874730219))
#                 align("qA3.resonator", "qA3.xy", "qA3.z")
#                 assign(a1[2], v119)
#                 align("qA4.resonator", "qA4.xy", "qA4.z")
#                 measure("readout", "qA4.resonator", dual_demod.full("iw1", "iw2", v123), dual_demod.full("iw3", "iw1", v124))
#                 assign(v122, (v123>-0.00014449193999423478))
#                 align("qA4.resonator", "qA4.xy", "qA4.z")
#                 assign(a1[3], v122)
#                 align("qA6.resonator", "qA6.xy", "qA6.z")
#                 measure("readout", "qA6.resonator", dual_demod.full("iw1", "iw2", v126), dual_demod.full("iw3", "iw1", v127))
#                 assign(v125, (v126>0.0008141418019060033))
#                 align("qA6.resonator", "qA6.xy", "qA6.z")
#                 assign(a1[4], v125)
#                 align("qB1.resonator", "qB1.xy", "qB1.z")
#                 measure("readout", "qB1.resonator", dual_demod.full("iw1", "iw2", v129), dual_demod.full("iw3", "iw1", v130))
#                 assign(v128, (v129>0.0012358176158358415))
#                 align("qB1.resonator", "qB1.xy", "qB1.z")
#                 assign(a1[5], v128)
#                 align("qB2.resonator", "qB2.xy", "qB2.z")
#                 measure("readout", "qB2.resonator", dual_demod.full("iw1", "iw2", v132), dual_demod.full("iw3", "iw1", v133))
#                 assign(v131, (v132>0.0012232037284515098))
#                 align("qB2.resonator", "qB2.xy", "qB2.z")
#                 assign(a1[6], v131)
#                 align("qB3.resonator", "qB3.xy", "qB3.z")
#                 measure("readout", "qB3.resonator", dual_demod.full("iw1", "iw2", v135), dual_demod.full("iw3", "iw1", v136))
#                 assign(v134, (v135>0.0012403000540539956))
#                 align("qB3.resonator", "qB3.xy", "qB3.z")
#                 assign(a1[7], v134)
#                 align("qB4.resonator", "qB4.xy", "qB4.z")
#                 measure("readout", "qB4.resonator", dual_demod.full("iw1", "iw2", v138), dual_demod.full("iw3", "iw1", v139))
#                 assign(v137, (v138>0.0012071295676076435))
#                 align("qB4.resonator", "qB4.xy", "qB4.z")
#                 assign(a1[8], v137)
#                 align("qB5.resonator", "qB5.xy", "qB5.z")
#                 measure("readout", "qB5.resonator", dual_demod.full("iw1", "iw2", v141), dual_demod.full("iw3", "iw1", v142))
#                 assign(v140, (v141>0.0023589081316441546))
#                 align("qB5.resonator", "qB5.xy", "qB5.z")
#                 assign(a1[9], v140)
#                 align("qC1.resonator", "qC1.xy", "qC1.z")
#                 measure("readout", "qC1.resonator", dual_demod.full("iw1", "iw2", v144), dual_demod.full("iw3", "iw1", v145))
#                 assign(v143, (v144>0.00014968677947712738))
#                 align("qC1.resonator", "qC1.xy", "qC1.z")
#                 assign(a1[10], v143)
#                 align("qC2.resonator", "qC2.xy", "qC2.z")
#                 measure("readout", "qC2.resonator", dual_demod.full("iw1", "iw2", v147), dual_demod.full("iw3", "iw1", v148))
#                 assign(v146, (v147>0.00016926329503889285))
#                 align("qC2.resonator", "qC2.xy", "qC2.z")
#                 assign(a1[11], v146)
#                 align("qC4.resonator", "qC4.xy", "qC4.z")
#                 measure("readout", "qC4.resonator", dual_demod.full("iw1", "iw2", v150), dual_demod.full("iw3", "iw1", v151))
#                 assign(v149, (v150>0.0002390371513853697))
#                 align("qC4.resonator", "qC4.xy", "qC4.z")
#                 assign(a1[12], v149)
#                 align("qD1.resonator", "qD1.xy", "qD1.z")
#                 measure("readout", "qD1.resonator", dual_demod.full("iw1", "iw2", v153), dual_demod.full("iw3", "iw1", v154))
#                 assign(v152, (v153>0.0006627114274709664))
#                 align("qD1.resonator", "qD1.xy", "qD1.z")
#                 assign(a1[13], v152)
#                 align("qD2.resonator", "qD2.xy", "qD2.z")
#                 measure("readout", "qD2.resonator", dual_demod.full("iw1", "iw2", v156), dual_demod.full("iw3", "iw1", v157))
#                 assign(v155, (v156>0.0008867118558507442))
#                 align("qD2.resonator", "qD2.xy", "qD2.z")
#                 assign(a1[14], v155)
#                 align("qD3.resonator", "qD3.xy", "qD3.z")
#                 measure("readout", "qD3.resonator", dual_demod.full("iw1", "iw2", v159), dual_demod.full("iw3", "iw1", v160))
#                 assign(v158, (v159>0.0008193751879293711))
#                 align("qD3.resonator", "qD3.xy", "qD3.z")
#                 assign(a1[15], v158)
#                 align("qD4.resonator", "qD4.xy", "qD4.z")
#                 measure("readout", "qD4.resonator", dual_demod.full("iw1", "iw2", v162), dual_demod.full("iw3", "iw1", v163))
#                 assign(v161, (v162>0.0009560861598610923))
#                 align("qD4.resonator", "qD4.xy", "qD4.z")
#                 assign(a1[16], v161)
#                 align("qD5.resonator", "qD5.xy", "qD5.z")
#                 measure("readout", "qD5.resonator", dual_demod.full("iw1", "iw2", v165), dual_demod.full("iw3", "iw1", v166))
#                 assign(v164, (v165>0.0006576820851857754))
#                 align("qD5.resonator", "qD5.xy", "qD5.z")
#                 assign(a1[17], v164)
#                 with for_(v167,0,(v167<18),(v167+1)):
#                     r1 = declare_stream()
#                     save(a1[v167], r1)
#     with stream_processing():
#         r1.map(FUNCTIONS.boolean_to_int()).buffer(18).save_all("__c_0")
#
#
#     ####     SERIALIZATION VALIDATION ERROR     ####
#     #
#     #  name 'input_stream_param' is not defined
#     #
#     # Trace:
#     #   ['Traceback (most recent call last):\n', '  File "/Users/arthurostrauss/Documents/.venv/lib/python3.13/site-packages/qm/serialization/generate_qua_script.py", line 103, in _generate_qua_script_pb\n    extra_info = extra_info + _validate_program(proto_prog, serialized_program)\n                              ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n', '  File "/Users/arthurostrauss/Documents/.venv/lib/python3.13/site-packages/qm/serialization/generate_qua_script.py", line 127, in _validate_program\n    exec(serialized_program, generated_mod.__dict__)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n', '  File "<string>", line 196, in <module>\n', "NameError: name 'input_stream_param' is not defined\n"]
#     #
#     ################################################
#
#
# config = None
#
# loaded_config = None

# %%
from qiskit_qm_provider.parameter_table.parameter import InputType
estimator._job._execution_plans[0].observables_var.get_parameter(2).input_type == InputType.INPUT_STREAM
# Out:
# True
